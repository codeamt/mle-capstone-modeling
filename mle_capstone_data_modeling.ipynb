# %% [markdown]
# #Udacity MLE Nanodegree Capstone - Training
# Light-weight Data ModeEfficientnet and Fast.ai for Chest X-Ray (CXR) classification task; light-weight modeling for detecting upper-respitorty viral infenctions from Chests.

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ###Environment Setup:

# %%
# !pip install pthflops
# !pip install plotly_express
# !pip install pytorchcv
# Out:
# Collecting pthflops
#   Downloading https://files.pythonhosted.org/packages/aa/ba/01ea6b85cb7ee48cf12b6bf08104d5806a9304ade9bb4643dfad9bcdb024/pthflops-0.2.2.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pthflops) (1.5.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->pthflops) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->pthflops) (0.16.0)
# Building wheels for collected packages: pthflops
#   Building wheel for pthflops (setup.py) ... done
#   Created wheel for pthflops: filename=pthflops-0.2.2-cp36-none-any.whl size=5108 sha256=d75b32a7def610fd096eb17e11285168b68c17189e98d0f730bbe438905ac766
#   Stored in directory: /root/.cache/pip/wheels/f8/c8/14/8a85a906c6eba9ed3e1c331c4f66dc8c43a7b4953a88e04397
# Successfully built pthflops
# Installing collected packages: pthflops
# Successfully installed pthflops-0.2.2
# Collecting plotly_express
#   Downloading https://files.pythonhosted.org/packages/d4/d6/8a2906f51e073a4be80cab35cfa10e7a34853e60f3ed5304ac470852a08d/plotly_express-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.0.4)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (4.4.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.18.5)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.4.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.10.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->plotly_express) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2018.9)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=4.1.0->plotly_express) (1.3.3)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1
# Collecting pytorchcv
#   Downloading https://files.pythonhosted.org/packages/93/be/0bcd80dfc0d64e75ceb67836385402fece3c3b964c349172a21358813b25/pytorchcv-0.0.58-py2.py3-none-any.whl (435kB)
#      |████████████████████████████████| 440kB 4.5MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2020.4.5.1)
# Installing collected packages: pytorchcv
# Successfully installed pytorchcv-0.0.58

# %%
with open('/content/common.py','r') as writer_file:
    contents_to_write = writer_file.read()
with open('/usr/local/lib/python3.6/dist-packages/pytorchcv/models/common.py' ,'w') as file_to_overwrite:
    file_to_overwrite.write(contents_to_write)
    print("Restart Notebook/Kernel")
# Out:
# Restart Notebook/Kernel

# %% [markdown]
# ###Import Packages:

# %%
#utils
from __future__ import print_function
from __future__ import division
import os
import json
import zipfile
import shutil 

#
from sklearn.manifold import TSNE
import plotly_express as px

#data science/ml
from pytorchcv.model_provider import get_model as ptcv_get_model
import fastai
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.callbacks import HookCallback
from fastai.callbacks.tracker import EarlyStoppingCallback
from fastai.callbacks.tracker import SaveModelCallback
from fastai.callbacks.tracker import ReduceLROnPlateauCallback
  
import torch
import torch.utils.data
import torchvision
from torchvision.utils import make_grid
import numpy as np
import tracemalloc
from pthflops import count_ops

import warnings
warnings.filterwarnings('ignore')

# %%
print("Using fast.ai version: ", fastai.__version__)
# Out:
# Using fast.ai version:  1.0.61

# %% [markdown]
# ### Hardware Specs

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print("Hardware Specs: ")
  print(gpu_info)
# Out:
# Hardware Specs:
# Sun Jun 14 13:41:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |     10MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#directory with data and labels (in .csv format for this project)
path = Path("/content/drive/My Drive/fast_covid_net/")
path.ls()
# Out:
# [PosixPath('/content/drive/My Drive/fast_covid_net/data'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/train_split_v3.csv'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/test_split_v3.csv'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/extras')]

# %% [markdown]
# ### Creating Fastai Torch Dataloaders

# %%
#Basic hyperparameters 
bs = 16
size = 240

#Transforms to apply
tfms = [(contrast(scale=(1.5, 1.85), p=0.7),
         crop_pad(), 
         *zoom_crop(scale=(1.15,1.5), do_rand=True, p=.2)), ()]

# %%
#label df
print("Labeled Training Data; pandas DataFrame (DF)")
labels = pd.read_csv(path/'train_split_v3.csv', header='infer')
labels.head()
# Out:
# Labeled Training Data; pandas DataFrame (DF)
#   patient_id  ... label_short
# 0          3  ...          PA
# 1          3  ...          PA
# 2          3  ...          PA
# 3          7  ...          PA
# 4          7  ...          PA
#
# [5 rows x 4 columns]

# %% [markdown]
# Generate **ImageDataBunch** for training.
# Docs: https://docs.fast.ai/vision.data.html#ImageDataBunch

# %%
#Create ImageDataBunch from labels DF
data = ImageDataBunch.from_df(path, 
                              labels, 
                              folder='data/train', 
                              ds_tfms=tfms, 
                              fn_col=1, 
                              label_col=2, 
                              size=size, 
                              bs=bs)

data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (10904 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net;
#
# Valid: LabelList (2726 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,normal,pneumonia,pneumonia,normal
# Path: /content/drive/My Drive/fast_covid_net;
#
# Test: None

# %%
print("Sample Batch, Transformed")
data.show_batch(rows=3, figsize=(10, 10))
# Out:
# Sample Batch, Transformed

# %%
# From: https://github.com/ufoym/imbalanced-dataset-sampler/blob/master/torchsampler/imbalanced.py
class ImbalancedDatasetSampler(torch.utils.data.sampler.Sampler):
    """Samples elements randomly from a given list of indices for imbalanced dataset
    Args:
        - indices (list, optional): a list of indices
        - num_samples (int, optional): number of samples to draw
    """
    def __init__(self, dataset, indices=None, num_samples=None):
                
        # if indices is not provided, 
        # all elements in the dataset will be considered
        self.indices = list(range(len(dataset))) \
            if indices is None else indices
            
        # if num_samples is not provided, 
        # draw `len(indices)` samples in each iteration
        self.num_samples = len(self.indices) \
            if num_samples is None else num_samples
            
        # distribution of classes in the dataset 
        label_to_count = {}
        for idx in self.indices:
            label = self._get_label(dataset, idx)
            for l in label:
                if l in label_to_count:
                    label_to_count[l] += 1
                else: label_to_count[l]=1
        
        # weight for each sample
        weights = [1.0 / min([label_to_count[l] for l in self._get_label(dataset, idx)])
                   for idx in self.indices]
        self.weights = torch.DoubleTensor(weights)

    def _get_label(self, dataset, idx):
        return dataset.y[idx].obj #for category obj
                
    def __iter__(self):
        return (self.indices[i] for i in torch.multinomial(
            self.weights, self.num_samples, replacement=True))

    def __len__(self):
        return self.num_samples

# %%
def get_data(sz, tfs, batch=8, workers=4):
  """
  Automates the instantiation of DataLoaders with oversampling of 
  minority class. 
  Args: 
    - sz --> type:int --> img size.
    - tfms --> type:List --> transforms. 
    - batch --> type:int, default=8 --> batch size. 
    - workers --> type:int, default=4 --> number of workers for each dataloader   
  """
  data = ImageDataBunch.from_df(path, 
                                labels, 
                                folder='data/train', 
                                ds_tfms=tfs, fn_col=1, 
                                label_col=2, 
                                size=sz,
                                resize_method=ResizeMethod.SQUISH, 
                                bs=bs)
  data.normalize(imagenet_stats)
  train_ds, val_ds = data.train_ds, data.valid_ds
  sampler = ImbalancedDatasetSampler(train_ds)
  train_dl = DataLoader(train_ds, bs, sampler=sampler, num_workers=workers)
  val_dl = DataLoader(val_ds, 2*bs, False, num_workers=workers)
  
  data = ImageDataBunch(train_dl=train_dl, 
                        valid_dl=val_dl).normalize(imagenet_stats)
  return data

# %%
data = get_data(sz=size, tfs=tfms)

# %%
print("Sample Batch, Transformed and Resampled")
data.show_batch(rows=3, figsize=(10, 10))
# Out:
# Sample Batch, Transformed and Resampled

# %%
#Labels
print(f'Labels for this Task: {data.classes}')
# Out:
# Labels for this Task: ['COVID-19', 'normal', 'pneumonia']

# %%
effnet_features = ptcv_get_model("efficientnet_b1", pretrained=True).features
# Out:
# Downloading /root/.torch/models/efficientnet_b1-0638-ac77bcd7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.376/efficientnet_b1-0638-ac77bcd7.pth.zip...

# %%
def arch_summary(arch):
  """
  A helper for listing the sequential layer groups of the network
  Args:
    - arch --> type:nn.ModuleList --> A list of modules.
  https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/utils.py
  """
  model = arch(False)
  tot = 0
  for i, l in enumerate(model.children()):
      n_layers = len(flatten_model(l))
      tot += n_layers
      print(f'({i}) {l.__class__.__name__:<12}: {n_layers:<4}layers (total: {tot})')


def get_groups(m, layer_groups):
  """
  a helper method for listing the layer groups after the layer cuts have been 
  determined for discriminative learning rates.
  Args:
    - m --> type:nn.ModuleList/nn.Sequential --> A list of modules.
    - layer_groups --> type:list --> List of layers grouped by split defined in 
    Learner class. 
  """
  group_indices = [len(g) for g in layer_groups]
  curr_i = 0
  group = []
  for layer in model:
      group_indices[curr_i] -= len(flatten_model(layer))
      group.append(layer.__class__.__name__)
      if group_indices[curr_i] == 0:
          curr_i += 1
          print(f'Group {curr_i}:', group)   
          group = []

# %%
print("Model Blocks:")
arch_summary(lambda _: effnet_features)
# Out:
# Model Blocks:
# (0) EffiInitBlock: 3   layers (total: 3)
# (1) Sequential  : 20  layers (total: 23)
# (2) Sequential  : 39  layers (total: 62)
# (3) Sequential  : 39  layers (total: 101)
# (4) Sequential  : 104 layers (total: 205)
# (5) Sequential  : 91  layers (total: 296)
# (6) ConvBlock   : 3   layers (total: 299)
# (7) AdaptiveAvgPool2d: 1   layers (total: 300)

# %%
print("Model Blocks (Detailed):")
for i in range(len(effnet_features) - 1):
    print(f'---------({i})---------')
    arch_summary(lambda _: effnet_features[i])
# Out:
# Model Blocks (Detailed):
# ---------(0)---------
# (0) ConvBlock   : 3   layers (total: 3)
# ---------(1)---------
# (0) EffiDwsConvUnit: 10  layers (total: 10)
# (1) EffiDwsConvUnit: 10  layers (total: 20)
# ---------(2)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# ---------(3)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# ---------(4)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# (3) EffiInvResUnit: 13  layers (total: 52)
# (4) EffiInvResUnit: 13  layers (total: 65)
# (5) EffiInvResUnit: 13  layers (total: 78)
# (6) EffiInvResUnit: 13  layers (total: 91)
# (7) EffiInvResUnit: 13  layers (total: 104)
# ---------(5)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# (3) EffiInvResUnit: 13  layers (total: 52)
# (4) EffiInvResUnit: 13  layers (total: 65)
# (5) EffiInvResUnit: 13  layers (total: 78)
# (6) EffiInvResUnit: 13  layers (total: 91)
# ---------(6)---------
# (0) Conv2d      : 1   layers (total: 1)
# (1) BatchNorm2d : 1   layers (total: 2)
# (2) Swish       : 1   layers (total: 3)

# %%
def efficientnet_b1(pretrained=True):
  """
  Returns efficientnet-b1 feature extraction layers, using pytorchcv's
  ptcv_get_model helper method.
  Args:
    pretrained --> type:bool (default: True) 
  """
  return ptcv_get_model("efficientnet_b1", pretrained=pretrained).features

#Fastai Learner (Model with built-in Training Tools)
def get_learner(train_data):
  """
  Generates a fastai Learner with passed fastai ImageDataBunch data loaders and 
  feature extraction layers from a pretrained EfficientNet-b1 network. 
  Uses Half-Tensor Precision.
  Args:
    train_data --> type:ImageDataBunch  
  """
  learn = cnn_learner(train_data, 
                      efficientnet_b1, 
                      metrics=[error_rate, accuracy], 
                      callback_fns=[ShowGraph])
  return learn

# %%
#pretrained on ImageNet dataset - weights provided by pytorchcv library 
learn = get_learner(data)
print(learn.summary())
print("Loss Function: ", learn.loss_func)
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [32, 120, 120]       864        False
# ______________________________________________________________________
# BatchNorm2d          [32, 120, 120]       64         True
# ______________________________________________________________________
# Swish                [32, 120, 120]       0          False
# ______________________________________________________________________
# Conv2d               [32, 120, 120]       288        False
# ______________________________________________________________________
# BatchNorm2d          [32, 120, 120]       64         True
# ______________________________________________________________________
# Swish                [32, 120, 120]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [8, 1, 1]            264        False
# ______________________________________________________________________
# Swish                [8, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           288        False
# ______________________________________________________________________
# Sigmoid              [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       512        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       144        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Swish                [16, 120, 120]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [4, 1, 1]            68         False
# ______________________________________________________________________
# Swish                [4, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [16, 1, 1]           80         False
# ______________________________________________________________________
# Sigmoid              [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       256        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Conv2d               [96, 120, 120]       1,536      False
# ______________________________________________________________________
# BatchNorm2d          [96, 120, 120]       192        True
# ______________________________________________________________________
# Swish                [96, 120, 120]       0          False
# ______________________________________________________________________
# Conv2d               [96, 60, 60]         864        False
# ______________________________________________________________________
# BatchNorm2d          [96, 60, 60]         192        True
# ______________________________________________________________________
# Swish                [96, 60, 60]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [96, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [4, 1, 1]            388        False
# ______________________________________________________________________
# Swish                [4, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [96, 1, 1]           480        False
# ______________________________________________________________________
# Sigmoid              [96, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         2,304      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        1,296      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         3,456      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        1,296      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         3,456      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 30, 30]        3,600      False
# ______________________________________________________________________
# BatchNorm2d          [144, 30, 30]        288        True
# ______________________________________________________________________
# Swish                [144, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         5,760      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        6,000      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         9,600      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        6,000      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         9,600      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 15, 15]        2,160      False
# ______________________________________________________________________
# BatchNorm2d          [240, 15, 15]        480        True
# ______________________________________________________________________
# Swish                [240, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         19,200     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        12,000     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        53,760     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 8, 8]          16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 8, 8]          1,344      True
# ______________________________________________________________________
# Swish                [672, 8, 8]          0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          129,024    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         10,368     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [320, 8, 8]          368,640    False
# ______________________________________________________________________
# BatchNorm2d          [320, 8, 8]          640        True
# ______________________________________________________________________
# Conv2d               [1920, 8, 8]         614,400    False
# ______________________________________________________________________
# BatchNorm2d          [1920, 8, 8]         3,840      True
# ______________________________________________________________________
# Swish                [1920, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1920, 8, 8]         17,280     False
# ______________________________________________________________________
# BatchNorm2d          [1920, 8, 8]         3,840      True
# ______________________________________________________________________
# Swish                [1920, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1920, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [80, 1, 1]           153,680    False
# ______________________________________________________________________
# Swish                [80, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1920, 1, 1]         155,520    False
# ______________________________________________________________________
# Sigmoid              [1920, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [320, 8, 8]          614,400    False
# ______________________________________________________________________
# BatchNorm2d          [320, 8, 8]          640        True
# ______________________________________________________________________
# Conv2d               [1280, 8, 8]         409,600    False
# ______________________________________________________________________
# BatchNorm2d          [1280, 8, 8]         2,560      True
# ______________________________________________________________________
# Swish                [1280, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1280, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [1280, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [2560]               0          False
# ______________________________________________________________________
# BatchNorm1d          [2560]               5,120      True
# ______________________________________________________________________
# Dropout              [2560]               0          False
# ______________________________________________________________________
# Linear               [512]                1,311,232  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [3]                  1,539      True
# ______________________________________________________________________
#
# Total params: 7,832,099
# Total trainable params: 1,380,963
# Total non-trainable params: 6,451,136
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#
# Loss Function:  FlattenedLoss of CrossEntropyLoss()

# %%
gc.collect()
# Out:
# 36158

# %%
#https://www.kaggle.com/qitvision/a-complete-ml-pipeline-fast-ai/comments
def wd_grid_search(data, decay_list, frozen=False, plot_y_min=2.00, 
                   plot_y_max=3.80, plot_x_min=1e-6, plot_x_max=1e+00):
  """
  Wraps fastai Learner.Recorder.find_lr() method, loops through decay_list of
  weight decay values and visualizes performance on a test run to help select 
  the optimal amount of decay:
  Args:
    - data --> type:ImageDataBunch 
    - decay_list -> type:List[] -> list of weight decay values to test
    - frozen -> type:bool -> fine-tuning clasifier (True) or entire network (False)
    - plot_y_min, plot_y_max, plot_x_min, plot_x_max -> type:float
      -> ranges for axis of final chart on performance 
  """
  lrs = []
  losses = []
  wds = []

  def reset_learner():
    if frozen:
      learner = get_learner(data)
      learner.freeze()
      return learner
    else:
      learner = get_learner(data)
      learner.unfreeze()
      return learner

  learner = reset_learner()

  #Search w/o weight decay (baseline)
  learner.lr_find(num_it=300)
  lrs.append(learner.recorder.lrs)
  losses.append(learner.recorder.losses)
  wds.append('None')
  learner = reset_learner()

  #for each weight decay value, search for best learning rate 
  for item in decay_list: 
    learner.lr_find(num_it=300, wd=item)
    lrs.append(learner.recorder.lrs)
    losses.append(learner.recorder.losses)
    wds.append(str(item))
    reset_learner()

  #Plot losses for wd values over learning rates  
  _, ax = plt.subplots(1,1)
  min_y = plot_y_min
  max_y = plot_y_max
  min_x = plot_x_min
  max_x = plot_x_max
  for i in range(len(losses)):
    ax.plot(lrs[i], losses[i])
    min_y = min(np.isfinite(np.asarray(losses[i])).min(), min_y)
  ax.set_ylabel("Loss")
  ax.set_xlabel("Learning Rate")
  ax.set_xscale('log')
  #ax ranges may need some tuning with different model architectures 
  ax.set_xlim((min_x, max_x))
  ax.set_ylim((min_y, max_y))
  ax.legend(wds)
  ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%.0e'))

# %%
class TraceMallocMultiColMetric(LearnerCallback):
  """
  #Fastai Learner Callback to measures peak RAM usage during each epoch.
  Callbacks and Custom Metrics, Docs: #https://docs.fast.ai/metrics.html#Creating-your-own-metric
  """
  _order=-20 # Needs to run before the recorder
  def __init__(self, learn):
    super().__init__(learn)
    self.train_max = 0

  def on_train_begin(self, **kwargs):
    self.learn.recorder.add_metric_names(['used', 'max_used', 'peak'])
            
  def on_batch_end(self, train, **kwargs):
    # track max memory usage during the train phase
    if train:
      current, peak =  tracemalloc.get_traced_memory()
      self.train_max = max(self.train_max, current)
        
  def on_epoch_begin(self, **kwargs):
      tracemalloc.start()

  def on_epoch_end(self, last_metrics, **kwargs):
      current, peak =  tracemalloc.get_traced_memory()
      tracemalloc.stop()
      return add_metrics(last_metrics, [current, self.train_max, peak])

# %%
class StoreHook(HookCallback):
  """
  A fastai Custom Callback for storing a module's feature activations.
  More Info: https://forums.fast.ai/t/confused-by-output-of-hook-output/29514/4
  """
  def on_train_begin(self, **kwargs):
      super().on_train_begin(**kwargs)
      self.hists = []
        
  def hook(self, m, i, o): 
      return o
    
  def on_batch_end(self, train, **kwargs): 
      if (train): 
          self.hists.append(self.hooks.stored[0].cpu().histc(40,0,10))

# %% [markdown]
# ### Stage 1:

# %%
wd_grid_search(learn.data, 
               [2e-1, 2e-2, 2e-3, 2e-4], 
               frozen=False,
               plot_x_max=float(1e-1), 
               plot_y_min=1.00, 
               plot_y_max=2.25)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='240' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.19% [240/682 09:31<17:32 4.2734]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='251' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.80% [251/682 06:59<12:00 4.2010]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='246' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.07% [246/682 05:36<09:55 4.5012]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='240' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.19% [240/682 04:54<09:01 4.1328]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='240' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.19% [240/682 03:46<06:57 4.3372]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#garbage collection for gpu memory 
gc.collect()
# Out:
# 7254

# %%
#fit unfrozen, using one-cycle policy:
#appends callback to learners callback list for this run 
learn.callbacks.append(TraceMallocMultiColMetric(learn))
learn.unfreeze() 
learn.fit_one_cycle(5, slice(2e-3), wd=2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>used</th>
#       <th>max_used</th>
#       <th>peak</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.465557</td>
#       <td>0.298957</td>
#       <td>0.090976</td>
#       <td>0.909024</td>
#       <td>369554</td>
#       <td>438590</td>
#       <td>463275</td>
#       <td>18:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.297820</td>
#       <td>0.223738</td>
#       <td>0.076669</td>
#       <td>0.923331</td>
#       <td>221304</td>
#       <td>438590</td>
#       <td>314181</td>
#       <td>06:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.221415</td>
#       <td>0.195883</td>
#       <td>0.063096</td>
#       <td>0.936904</td>
#       <td>209753</td>
#       <td>438590</td>
#       <td>306362</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119141</td>
#       <td>0.174575</td>
#       <td>0.056126</td>
#       <td>0.943874</td>
#       <td>231376</td>
#       <td>438590</td>
#       <td>327569</td>
#       <td>05:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.081067</td>
#       <td>0.167914</td>
#       <td>0.053558</td>
#       <td>0.946442</td>
#       <td>249567</td>
#       <td>438590</td>
#       <td>345504</td>
#       <td>05:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Save checkpoint
learn.save('eff_covid_1')

# %%
sample = torch.randn(1, 3, 240, 240).cuda() 
print("FLOPs Count")
count_ops(learn.model, sample, )
# Out:
# FLOPs Count
# Operation                   OPS
# --------------------------  ---------
# /onnx::Conv                 12902400
# /onnx::BatchNormalization   921600
# /onnx::Conv                 4147200
# /onnx::BatchNormalization   921600
# /onnx::GlobalAveragePool    460800
# /onnx::Conv                 256
# /onnx::Conv                 256
# /onnx::Mul                  460800
# /onnx::Conv                 7372800
# /onnx::BatchNormalization   460800
# /onnx::Conv                 2073600
# /onnx::BatchNormalization   460800
# /onnx::GlobalAveragePool    230400
# /onnx::Conv                 64
# /onnx::Conv                 64
# /onnx::Mul                  230400
# /onnx::Conv                 3686400
# /onnx::BatchNormalization   460800
# /onnx::Add                  230400
# /onnx::Conv                 22118400
# /onnx::BatchNormalization   2764800
# /onnx::Conv                 3110400
# /onnx::BatchNormalization   691200
# /onnx::GlobalAveragePool    345600
# /onnx::Conv                 384
# /onnx::Conv                 384
# /onnx::Mul                  345600
# /onnx::Conv                 8294400
# /onnx::BatchNormalization   172800
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 3240000
# /onnx::BatchNormalization   259200
# /onnx::GlobalAveragePool    129600
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  129600
# /onnx::Conv                 5184000
# /onnx::BatchNormalization   72000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 486000
# /onnx::BatchNormalization   108000
# /onnx::GlobalAveragePool    54000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  54000
# /onnx::Conv                 4320000
# /onnx::BatchNormalization   36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 2700000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 12096000
# /onnx::BatchNormalization   50400
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 1075200
# /onnx::BatchNormalization   86016
# /onnx::GlobalAveragePool    43008
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  43008
# /onnx::Conv                 8257536
# /onnx::BatchNormalization   24576
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 663552
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 23592960
# /onnx::BatchNormalization   40960
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   245760
# /onnx::Conv                 1105920
# /onnx::BatchNormalization   245760
# /onnx::GlobalAveragePool    122880
# /onnx::Conv                 153600
# /onnx::Conv                 153600
# /onnx::Mul                  122880
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   40960
# /onnx::Add                  20480
# /onnx::Conv                 26214400
# /onnx::BatchNormalization   163840
# /onnx::MaxPool              80640
# /onnx::GlobalAveragePool    81920
# /onnx::BatchNormalization   5120
# /onnx::Gemm                 1310720
# /onnx::Relu                 1024
# /onnx::BatchNormalization   1024
# /onnx::Gemm                 1536
# -------------------------   --------
# Input size: (1, 3, 240, 240)
# 718,097,040 FLOPs or approx. 0.72 GFLOPs
# (718097040,
#  [['/onnx::Conv', 12902400],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::Conv', 4147200],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::GlobalAveragePool', 460800],
#   ['/onnx::Conv', 256],
#   ['/onnx::Conv', 256],
#   ['/onnx::Mul', 460800],
#   ['/onnx::Conv', 7372800],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Conv', 2073600],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::GlobalAveragePool', 230400],
#   ['/onnx::Conv', 64],
#   ['/onnx::Conv', 64],
#   ['/onnx::Mul', 230400],
#   ['/onnx::Conv', 3686400],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Add', 230400],
#   ['/onnx::Conv', 22118400],
#   ['/onnx::BatchNormalization', 2764800],
#   ['/onnx::Conv', 3110400],
#   ['/onnx::BatchNormalization', 691200],
#   ['/onnx::GlobalAveragePool', 345600],
#   ['/onnx::Conv', 384],
#   ['/onnx::Conv', 384],
#   ['/onnx::Mul', 345600],
#   ['/onnx::Conv', 8294400],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 3240000],
#   ['/onnx::BatchNormalization', 259200],
#   ['/onnx::GlobalAveragePool', 129600],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 129600],
#   ['/onnx::Conv', 5184000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 486000],
#   ['/onnx::BatchNormalization', 108000],
#   ['/onnx::GlobalAveragePool', 54000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 54000],
#   ['/onnx::Conv', 4320000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 2700000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 12096000],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 1075200],
#   ['/onnx::BatchNormalization', 86016],
#   ['/onnx::GlobalAveragePool', 43008],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 43008],
#   ['/onnx::Conv', 8257536],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 663552],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 23592960],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::Conv', 1105920],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::GlobalAveragePool', 122880],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Mul', 122880],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Add', 20480],
#   ['/onnx::Conv', 26214400],
#   ['/onnx::BatchNormalization', 163840],
#   ['/onnx::MaxPool', 80640],
#   ['/onnx::GlobalAveragePool', 81920],
#   ['/onnx::BatchNormalization', 5120],
#   ['/onnx::Gemm', 1310720],
#   ['/onnx::Relu', 1024],
#   ['/onnx::BatchNormalization', 1024],
#   ['/onnx::Gemm', 1536]])

# %% [markdown]
# ### Stage 2:

# %%
gc.collect()
data2 = get_data(size, tfms)
learn = get_learner(data2)
learn.load('eff_covid_1')
wd_grid_search(learn.data, 
               [2e-1, 2e-2, 2e-3, 2e-4], #hparam search
               frozen=True, 
               plot_x_max=float(1e-1), 
               plot_y_min=1.0,
               plot_y_max=2.25)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='250' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.66% [250/682 01:31<02:38 5.0230]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='257' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       37.68% [257/682 01:40<02:45 4.9133]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='247' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.22% [247/682 01:33<02:45 4.9010]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='247' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.22% [247/682 01:33<02:44 5.0668]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='250' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.66% [250/682 01:31<02:38 5.0868]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#fit frozen, using one-cycle policy: 
gc.collect()
learn.callbacks.append(TraceMallocMultiColMetric(learn))
learn.freeze()
learn.fit_one_cycle(3, max_lr=slice(5e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>used</th>
#       <th>max_used</th>
#       <th>peak</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.159986</td>
#       <td>0.131879</td>
#       <td>0.037051</td>
#       <td>0.962949</td>
#       <td>279226</td>
#       <td>358589</td>
#       <td>380217</td>
#       <td>05:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.145843</td>
#       <td>0.104614</td>
#       <td>0.029347</td>
#       <td>0.970653</td>
#       <td>200366</td>
#       <td>358589</td>
#       <td>300197</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.105136</td>
#       <td>0.098749</td>
#       <td>0.027513</td>
#       <td>0.972487</td>
#       <td>200489</td>
#       <td>358589</td>
#       <td>300800</td>
#       <td>05:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Save checkpoint
learn.save('eff_covid_2')

# %%
count_ops(learn.model, sample, )
# Out:
# Operation                   OPS
# --------------------------  ---------
# /onnx::Conv                 12902400
# /onnx::BatchNormalization   921600
# /onnx::Conv                 4147200
# /onnx::BatchNormalization   921600
# /onnx::GlobalAveragePool    460800
# /onnx::Conv                 256
# /onnx::Conv                 256
# /onnx::Mul                  460800
# /onnx::Conv                 7372800
# /onnx::BatchNormalization   460800
# /onnx::Conv                 2073600
# /onnx::BatchNormalization   460800
# /onnx::GlobalAveragePool    230400
# /onnx::Conv                 64
# /onnx::Conv                 64
# /onnx::Mul                  230400
# /onnx::Conv                 3686400
# /onnx::BatchNormalization   460800
# /onnx::Add                  230400
# /onnx::Conv                 22118400
# /onnx::BatchNormalization   2764800
# /onnx::Conv                 3110400
# /onnx::BatchNormalization   691200
# /onnx::GlobalAveragePool    345600
# /onnx::Conv                 384
# /onnx::Conv                 384
# /onnx::Mul                  345600
# /onnx::Conv                 8294400
# /onnx::BatchNormalization   172800
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 3240000
# /onnx::BatchNormalization   259200
# /onnx::GlobalAveragePool    129600
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  129600
# /onnx::Conv                 5184000
# /onnx::BatchNormalization   72000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 486000
# /onnx::BatchNormalization   108000
# /onnx::GlobalAveragePool    54000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  54000
# /onnx::Conv                 4320000
# /onnx::BatchNormalization   36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 2700000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 12096000
# /onnx::BatchNormalization   50400
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 1075200
# /onnx::BatchNormalization   86016
# /onnx::GlobalAveragePool    43008
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  43008
# /onnx::Conv                 8257536
# /onnx::BatchNormalization   24576
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 663552
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 23592960
# /onnx::BatchNormalization   40960
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   245760
# /onnx::Conv                 1105920
# /onnx::BatchNormalization   245760
# /onnx::GlobalAveragePool    122880
# /onnx::Conv                 153600
# /onnx::Conv                 153600
# /onnx::Mul                  122880
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   40960
# /onnx::Add                  20480
# /onnx::Conv                 26214400
# /onnx::BatchNormalization   163840
# /onnx::MaxPool              80640
# /onnx::GlobalAveragePool    81920
# /onnx::BatchNormalization   5120
# /onnx::Gemm                 1310720
# /onnx::Relu                 1024
# /onnx::BatchNormalization   1024
# /onnx::Gemm                 1536
# -------------------------   --------
# Input size: (1, 3, 240, 240)
# 718,097,040 FLOPs or approx. 0.72 GFLOPs
# (718097040,
#  [['/onnx::Conv', 12902400],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::Conv', 4147200],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::GlobalAveragePool', 460800],
#   ['/onnx::Conv', 256],
#   ['/onnx::Conv', 256],
#   ['/onnx::Mul', 460800],
#   ['/onnx::Conv', 7372800],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Conv', 2073600],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::GlobalAveragePool', 230400],
#   ['/onnx::Conv', 64],
#   ['/onnx::Conv', 64],
#   ['/onnx::Mul', 230400],
#   ['/onnx::Conv', 3686400],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Add', 230400],
#   ['/onnx::Conv', 22118400],
#   ['/onnx::BatchNormalization', 2764800],
#   ['/onnx::Conv', 3110400],
#   ['/onnx::BatchNormalization', 691200],
#   ['/onnx::GlobalAveragePool', 345600],
#   ['/onnx::Conv', 384],
#   ['/onnx::Conv', 384],
#   ['/onnx::Mul', 345600],
#   ['/onnx::Conv', 8294400],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 3240000],
#   ['/onnx::BatchNormalization', 259200],
#   ['/onnx::GlobalAveragePool', 129600],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 129600],
#   ['/onnx::Conv', 5184000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 486000],
#   ['/onnx::BatchNormalization', 108000],
#   ['/onnx::GlobalAveragePool', 54000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 54000],
#   ['/onnx::Conv', 4320000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 2700000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 12096000],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 1075200],
#   ['/onnx::BatchNormalization', 86016],
#   ['/onnx::GlobalAveragePool', 43008],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 43008],
#   ['/onnx::Conv', 8257536],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 663552],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 23592960],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::Conv', 1105920],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::GlobalAveragePool', 122880],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Mul', 122880],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Add', 20480],
#   ['/onnx::Conv', 26214400],
#   ['/onnx::BatchNormalization', 163840],
#   ['/onnx::MaxPool', 80640],
#   ['/onnx::GlobalAveragePool', 81920],
#   ['/onnx::BatchNormalization', 5120],
#   ['/onnx::Gemm', 1310720],
#   ['/onnx::Relu', 1024],
#   ['/onnx::BatchNormalization', 1024],
#   ['/onnx::Gemm', 1536]])

# %% [markdown]
# ### Save Weights

# %%
#save serialized fastai learner and recorder info
learn.export(file=path/'e-covidnet.pkl')
import torch
#save model state/weights (.pth file) for cpu inference
torch.save(learn.model.state_dict(), path/"e-covidnet.pth")

# %% [markdown]
# ### Analysis
# Using Fast.ai **ClassificationInterpretation** class to aggregate performance metrics and other insights.
#
# Docs for ClassificationInterpretation: https://docs.fast.ai/vision.learner.html#ClassificationInterpretation

# %%
class ImageEmbeddings(): 
  '''
  PyTorch Hook for storing linear features of images.
  Args:
    - m --> type:nn.Module --> Linear Layer of model. 
  '''
  features=None
  def __init__(self, m): 
        self.hook = m.register_forward_hook(self.hook_fn)
        self.features = None

  def hook_fn(self, module, input, output): 
        out = output.detach().cpu().numpy()
        if isinstance(self.features, type(None)):
            self.features = out
        else:
            self.features = np.row_stack((self.features, out))

  def remove(self): 
        self.hook.remove()

# %%
def df_for_projection(dataset, train_set=True):
  """

  """
  df=None
  if train_set:
    img_path = [str(x) for x in (list(dataset.train_ds.items) +list(dataset.valid_ds.items))]
    label = [dataset.classes[x] for x in (list(dataset.train_ds.y.items) +list(dataset.valid_ds.y.items))]
    label_id = [x for x in (list(dataset.train_ds.y.items) +list(dataset.valid_ds.y.items))]
    df = pd.DataFrame({'img_path': img_path, 'label': label, 'label_id': label_id})
  else: 
    img_path = [str(x) for x in (list(dataset.test_ds.items))]
    label = [dataset.classes[x] for x in (list(dataset.test_ds.y.items))]
    label_id = [x for x in (list(dataset.test_ds.y.items))]
    df = pd.DataFrame({'img_path': img_path, 'label': label, 'label_id': label_id})
  return df

# %%
def append_features(proj_df, embeddings):
  """
  """
  feature_vector = np.array(embeddings.features)
  x=feature_vector.tolist()
  proj_df['img_repr'] = x
  return proj_df

# %%
def project_data(df, components=3, perplexity=50, iterate=500):
  """
  """
  img_repr_matrix = [list(x) for x in df['img_repr'].values]
  tsne = TSNE(n_components=components, 
                    verbose=10, 
                    init='pca', 
                    perplexity=perplexity, 
                    n_iter=iterate, 
                    n_iter_without_progress=100)
  
  tsne_results_3 = tsne.fit_transform(img_repr_matrix)
  df['tsne1'] = tsne_results_3[:,0]
  df['tsne2'] = tsne_results_3[:,1]
  df['tsne3'] = tsne_results_3[:,2]
  return df

# %%
train_projection_df = df_for_projection(learn.data)
train_projection_df.head()
# Out:
#                                             img_path      label  label_id
# 0  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 1  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 2  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 3  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 4  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
#Run through training set one time to hook embeddings
train_features = learn.model[1][4]
train_embeddings = ImageEmbeddings(train_features)
_= learn.get_preds(data.train_ds)
_= learn.get_preds(DatasetType.Valid)

# %%
print(f'Train Embedding Size: {len(train_embeddings.features)}')
# Out:
# Train Embedding Size: 13630

# %%
train_projection_df = append_features(train_projection_df, train_embeddings)
train_projection_df.head()
# Out:
#                                             img_path  ...                                           img_repr
# 0  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [-72.17062377929688, 74.84928894042969, 20.130...
# 1  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [1.8983867168426514, -182.30621337890625, -195...
# 2  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [-174.20457458496094, 104.37997436523438, 91.8...
# 3  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [26.675342559814453, -158.18740844726562, -155...
# 4  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [-71.93968200683594, 73.98326110839844, 48.982...
#
# [5 rows x 4 columns]

# %%
train_projection_df = project_data(train_projection_df, perplexity=50, iterate=2000)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 13630 samples in 0.932s...
# [t-SNE] Computed neighbors for 13630 samples in 27.241s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13630
# [t-SNE] Computed conditional probabilities for sample 2000 / 13630
# [t-SNE] Computed conditional probabilities for sample 3000 / 13630
# [t-SNE] Computed conditional probabilities for sample 4000 / 13630
# [t-SNE] Computed conditional probabilities for sample 5000 / 13630
# [t-SNE] Computed conditional probabilities for sample 6000 / 13630
# [t-SNE] Computed conditional probabilities for sample 7000 / 13630
# [t-SNE] Computed conditional probabilities for sample 8000 / 13630
# [t-SNE] Computed conditional probabilities for sample 9000 / 13630
# [t-SNE] Computed conditional probabilities for sample 10000 / 13630
# [t-SNE] Computed conditional probabilities for sample 11000 / 13630
# [t-SNE] Computed conditional probabilities for sample 12000 / 13630
# [t-SNE] Computed conditional probabilities for sample 13000 / 13630
# [t-SNE] Computed conditional probabilities for sample 13630 / 13630
# [t-SNE] Mean sigma: 48.846731
# [t-SNE] Computed conditional probabilities in 1.615s
# [t-SNE] Iteration 50: error = 78.3209534, gradient norm = 0.0214124 (50 iterations in 51.204s)
# [t-SNE] Iteration 100: error = 75.5329666, gradient norm = 0.0046774 (50 iterations in 51.836s)
# [t-SNE] Iteration 150: error = 73.8341675, gradient norm = 0.0020746 (50 iterations in 51.720s)
# [t-SNE] Iteration 200: error = 71.5573196, gradient norm = 0.0002750 (50 iterations in 51.816s)
# [t-SNE] Iteration 250: error = 74.2415771, gradient norm = 0.0008276 (50 iterations in 51.596s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.241577
# [t-SNE] Iteration 300: error = 2.8499770, gradient norm = 0.0003680 (50 iterations in 51.635s)
# [t-SNE] Iteration 350: error = 2.4894927, gradient norm = 0.0001515 (50 iterations in 52.494s)
# [t-SNE] Iteration 400: error = 2.3228257, gradient norm = 0.0000895 (50 iterations in 53.508s)
# [t-SNE] Iteration 450: error = 2.2367997, gradient norm = 0.0000579 (50 iterations in 54.117s)
# [t-SNE] Iteration 500: error = 2.1772087, gradient norm = 0.0000413 (50 iterations in 50.341s)
# [t-SNE] Iteration 550: error = 2.1554899, gradient norm = 0.0000324 (50 iterations in 38.783s)
# [t-SNE] Iteration 600: error = 2.1267977, gradient norm = 0.0000260 (50 iterations in 29.570s)
# [t-SNE] Iteration 650: error = 2.0981743, gradient norm = 0.0000215 (50 iterations in 25.944s)
# [t-SNE] Iteration 700: error = 2.0752127, gradient norm = 0.0000181 (50 iterations in 26.105s)
# [t-SNE] Iteration 750: error = 2.1911144, gradient norm = 0.0000137 (50 iterations in 26.054s)
# [t-SNE] Iteration 800: error = 2.0745430, gradient norm = 0.0000141 (50 iterations in 23.135s)
# [t-SNE] Iteration 850: error = 2.0750380, gradient norm = 0.0000127 (50 iterations in 18.186s)
# [t-SNE] Iteration 900: error = 2.0680740, gradient norm = 0.0000115 (50 iterations in 17.597s)
# [t-SNE] Iteration 950: error = 2.0770266, gradient norm = 0.0000106 (50 iterations in 17.470s)
# [t-SNE] Iteration 1000: error = 2.0770495, gradient norm = 0.0000099 (50 iterations in 19.866s)
# [t-SNE] Iteration 1050: error = 2.0639689, gradient norm = 0.0000091 (50 iterations in 20.258s)
# [t-SNE] Iteration 1100: error = 2.0516376, gradient norm = 0.0000083 (50 iterations in 20.368s)
# [t-SNE] Iteration 1150: error = 2.0530422, gradient norm = 0.0000079 (50 iterations in 17.044s)
# [t-SNE] Iteration 1200: error = 2.0564966, gradient norm = 0.0000076 (50 iterations in 16.849s)
# [t-SNE] Iteration 1250: error = 2.0556161, gradient norm = 0.0000073 (50 iterations in 17.372s)
# [t-SNE] Iteration 1250: did not make any progress during the last 100 episodes. Finished.
# [t-SNE] KL divergence after 1250 iterations: 2.055616

# %%
#Visualize Img Distribution in 3 Dimensions
train_projection_df.to_parquet('similar_images')
px.scatter_3d(train_projection_df, 
              x='tsne1', 
              y='tsne2', 
              z='tsne3', 
              color='label', 
              title="Train Set Distribution - Scatter Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3bc0db2a-c14f-403a-af52-b9deed24f94f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3bc0db2a-c14f-403a-af52-b9deed24f94f")) {
#                     Plotly.newPlot(
#                         '3bc0db2a-c14f-403a-af52-b9deed24f94f',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "label=pneumonia<br>tsne1=%{x}<br>tsne2=%{y}<br>tsne3=%{z}", "legendgroup": "label=pneumonia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "label=pneumonia", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-389.6338806152344, -1394.5301513671875, 4645.5234375, -1558.95458984375, -307.14459228515625, -1655.202392578125, -1147.1971435546875, -288.8720703125, -1646.6962890625, -1415.38427734375, -1685.403076171875, -1221.8216552734375, -828.0072631835938, -776.4031372070312, -1577.0330810546875, -1580.1180419921875, -1795.6561279296875, -1433.9224853515625, -1304.3671875, 4434.94970703125, 2508.712890625, -1040.5025634765625, 11334.2607421875, -1125.0128173828125, 1866.92333984375, -1436.300537109375, 7475.9208984375, -1740.1180419921875, -1654.7752685546875, 740.4899291992188, -1724.278076171875, -1067.730224609375, -1199.059814453125, 4117.38134765625, 5211.23974609375, -1706.380859375, -1273.585693359375, -1453.263671875, -1320.1312255859375, 4293.3310546875, -1641.4942626953125, -1174.8702392578125, -1460.99462890625, -1653.4500732421875, -1524.451904296875, -763.2923583984375, 323.1826477050781, -1509.1490478515625, -1592.233154296875, -1475.54541015625, -1497.484375, -1446.0079345703125, -1706.48828125, 2469.99853515625, 657.1325073242188, 788.065185546875, -894.6593017578125, -1133.03857421875, -910.98681640625, -1093.0225830078125, -1580.5181884765625, -724.8757934570312, -1595.088623046875, -1381.56689453125, 1072.192138671875, 2966.94384765625, -1375.42626953125, -1323.4896240234375, 1261.0609130859375, -1427.872802734375, -1582.9239501953125, -1327.65625, -98.8001708984375, 10995.94921875, -1179.589599609375, 286.1702880859375, -1567.640625, -1106.46728515625, -1415.7352294921875, -1611.418212890625, -853.6002197265625, -1720.760009765625, -1252.2418212890625, -1221.3330078125, -1469.9794921875, -1306.3486328125, -1631.904052734375, -1120.0960693359375, -1248.126953125, 4864.947265625, 904.47412109375, -1438.730224609375, -439.5323791503906, -1559.645751953125, -1484.3421630859375, 86.15890502929688, -1741.8607177734375, 767.1718139648438, -1875.9273681640625, -1115.0899658203125, -1296.16552734375, -118.97162628173828, -1482.4305419921875, 10801.3984375, 2407.91845703125, -1687.9466552734375, -1147.22119140625, -1509.3929443359375, -1527.489013671875, -1643.0960693359375, -691.3818359375, -1386.434326171875, -1123.8238525390625, -1288.33203125, -1101.3846435546875, -1635.5198974609375, -1523.8494873046875, -480.236328125, -1286.17529296875, -114.79779815673828, -1207.48779296875, -1565.5953369140625, -1673.0601806640625, 13830.064453125, -47.97514724731445, 7543.27685546875, -1602.4344482421875, -1626.88427734375, -969.0028686523438, -587.2634887695312, -1303.2607421875, -1603.5819091796875, -357.2982177734375, -1364.7789306640625, -1307.95849609375, -1627.135986328125, -1317.5943603515625, 5565.3271484375, -132.59474182128906, -1301.19580078125, -1652.5340576171875, -1305.3575439453125, 8276.2578125, 1867.343994140625, -1065.8179931640625, -1457.0721435546875, -1647.3271484375, -1465.9686279296875, -1580.28466796875, -577.00244140625, -1483.03857421875, -1663.4622802734375, -1437.613037109375, 206.3517303466797, 1264.2789306640625, -1457.332275390625, -1140.2127685546875, -1210.971435546875, -1204.70458984375, -1164.90234375, -1262.662109375, -1586.9556884765625, 2635.2802734375, -1647.8131103515625, -467.5433044433594, -1178.4718017578125, -1682.8477783203125, -1356.90673828125, 1216.1024169921875, -421.6840515136719, -1577.991943359375, -1129.429443359375, -1623.881591796875, -1706.641845703125, -1216.342041015625, 1826.0050048828125, -1213.7978515625, -981.04931640625, 423.5948791503906, -1689.0562744140625, -1614.9833984375, -1220.0574951171875, -1236.873779296875, -1668.80712890625, -1207.9498291015625, -832.286376953125, -1500.30859375, -253.65679931640625, -401.06585693359375, -1322.9 ...

# %%
train_projection_df.describe()
# Out:
#            label_id         tsne1         tsne2         tsne3
# count  13630.000000  13630.000000  13630.000000  13630.000000
# mean       1.384299      0.163329     -0.473470      1.965883
# std        0.517579   2754.993896   1139.404053    782.550293
# min        0.000000 -11400.430664 -12181.952148 -16648.443359
# 25%        1.000000  -1486.457001   -866.993729   -494.240402
# 50%        1.000000  -1160.554565   -222.855476    143.774467
# 75%        2.000000    208.121887    978.719528    377.534256
# max        2.000000  18303.570312  20323.500000  21499.320312

# %%
'''
plot_top_losses() --> https://docs.fast.ai/vision.learner.html#_cl_int_plot_top_losses
Show images in top_losses along with their prediction, actual, loss, 
and probability of actual class.
'''
interp.plot_top_losses(9, figsize=(13,13))

# %%
'''
plot_confusion_matrix() --> 
https://docs.fast.ai/train.html#ClassificationInterpretation.plot_confusion_matrix
Plot the confusion matrix, with title and using cmap.
'''
interp.plot_confusion_matrix(figsize=(8,8), dpi=60)

# %%
'''
most_confused() --> 
https://docs.fast.ai/train.html#ClassificationInterpretation.most_confused
Sorted descending list of largest non-diagonal entries of confusion matrix, 
presented as actual, predicted, number of occurrences.
'''
print("Most Confused Classes")
interp.most_confused(min_val=2)
# Out:
# Most Confused Classes
# [('pneumonia', 'normal', 49),
#  ('normal', 'pneumonia', 22),
#  ('COVID-19', 'pneumonia', 2)]

# %%
print(interp.confusion_matrix())
# Out:
# [[  45    1    2]
#  [   0 1588   22]
#  [   1   49 1018]]

# %%
def get_metrics(cm):
  """
  Tabulates relevant metrics for medical diagnosis from stored rows/diagonal 
  entries of confusion matrics; Returns an array of metrics:true positives (tp), 
  false positives (fp), true negatives (tn), and false negatives (fn) for each
  class in a 3x3 confusion matrix (12 int64 values).
  Args:
    cm --> type:np.darray --> a confusion matrix.
  """
  tp_c1 = cm[0][0]
  fp_c1 = cm[1][0] + cm[2][0]
  tn_c1 = np.sum(cm) - tp_c1
  fn_c1 = cm[0][1] + cm[0][2]

  tp_c2 = cm[1][1]
  fp_c2 = cm[0][1] + cm[2][1]
  tn_c2 = np.sum(cm) - tp_c2
  fn_c2 = cm[1][0] + cm[1][2]

  tp_c3 = cm[2][2]
  fp_c3 = cm[0][2] + cm[1][2]
  tn_c3 = np.sum(cm) - tp_c3
  fn_c3 = cm[2][0] + cm[2][1]

  return [tp_c1,fp_c1,tn_c1,fn_c1,tp_c2,fp_c2,tn_c2,fn_c2, tp_c3,fp_c3,tn_c3,fn_c3]

# %%
train_conf_matrix = interp.confusion_matrix()
training_metrics = get_metrics(train_conf_matrix)
print(training_metrics)
# Out:
# [45, 1, 2681, 3, 1588, 50, 1138, 22, 1018, 24, 1708, 50]

# %%
#Precision for each class 
covid_precision = training_metrics[0]/(training_metrics[0]+training_metrics[1])
norm_precision = training_metrics[4]/(training_metrics[4]+training_metrics[5])
pneum_precision = training_metrics[8]/(training_metrics[8]+training_metrics[9])

train_precision_scores = {
    "COVID-19": covid_precision,
    "NORMAL": norm_precision,
    "PNEUMONIA": pneum_precision
}

train_precision_scores = pd.DataFrame(train_precision_scores, 
                                      columns=train_precision_scores.keys(), 
                                      index=[0])
print("Precision Scores:")
train_precision_scores
# Out:
# Precision Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.978261  0.969475   0.976967

# %%
#Recall for each class 
covid_recall = training_metrics[0]/(training_metrics[0]+training_metrics[3])
norm_recall = training_metrics[4]/(training_metrics[4]+training_metrics[7])
pneum_recall = training_metrics[8]/(training_metrics[8]+training_metrics[11])

train_sensitivity_scores = {
    "COVID-19": covid_recall, 
    "NORMAL": norm_recall,
    "PNEUMONIA": pneum_recall
}

train_sensitivity_scores = pd.DataFrame(train_sensitivity_scores, 
                         columns=train_sensitivity_scores.keys(), 
                         index=[0])
print("Sensitivity Scores:")
train_sensitivity_scores
# Out:
# Sensitivity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0    0.9375  0.986335   0.953184

# %%
#F1 Score for each class 
covid_f1 = 2*(covid_precision*covid_recall)/(covid_precision+covid_recall)
norm_f1 = 2 * (norm_precision*norm_recall)/(norm_precision + norm_recall)
pneum_f1 = 2 * (pneum_precision*pneum_recall)/(pneum_precision+pneum_recall)

train_f1_scores = {
    "COVID-19": covid_f1,
    "NORMAL": norm_f1,
    "PNEUMONIA": pneum_f1
}

train_f1_scores = pd.DataFrame(train_f1_scores, 
                         columns=train_f1_scores.keys(), 
                         index=[0])
print("F1 Scores:")
train_f1_scores
# Out:
# F1 Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.957447  0.977833   0.964929

# %%
#Specificity for each class 
covid_specificity = training_metrics[2]/(training_metrics[2]+training_metrics[1])
norm_specificity = training_metrics[6]/(training_metrics[6]+training_metrics[5])
pneum_specificity = training_metrics[10]/(training_metrics[10]+training_metrics[9])

specificity_scores = {"COVID-19": covid_specificity, 
                      "NORMAL": norm_specificity, 
                      "PNEUMONIA": pneum_specificity}
                      
specificity_df = pd.DataFrame(specificity_scores, 
                              columns=specificity_scores.keys(), 
                              index=[0])
print("Specificity Scores:")
specificity_df
# Out:
# Specificity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.999627  0.957912   0.986143

# %% [markdown]
# ### Inference Test & Results:

# %%
test_labels = pd.read_csv(path/'test_split_v3.csv', header='infer')
test_data_df = test_labels[["fname", "label"]]
print("Test Set Labels:")
test_data_df.head()
# Out:
# Test Set Labels:
#                                                fname      label
# 0  SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9...  pneumonia
# 1  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 2  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 3  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 4  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia

# %%
#Create a Fast.ai ImageList for creating inference data loaders
il = ImageList.from_df(test_data_df, path/'data/test')
ils = il.split_none()
ll = ils.label_from_df()
ll.valid = ll.train
ll.test = ll.train

# %%
#Apply test time transforms (None) 
test_size = 240
ll.transform(tfms=tfms,size=test_size)
#Create DataLoaders 
test_data = ll.databunch(bs=bs)
#Normalize --> Imagenet Stats 
test_data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (1510 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test;
#
# Valid: LabelList (1510 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test;
#
# Test: LabelList (1510 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test

# %%
#Load serialized learner and weights
test_learn = load_learner(path, file='e-covidnet.pkl')
#Attach test data to Learner 
test_learn.data = test_data

# %%
test_features = test_learn.model[1][4]
test_embeddings = ImageEmbeddings(test_features)

# %%
#Run inference
# %time results = test_learn.get_preds(ds_type=DatasetType.Test)
# Out:
# CPU times: user 2.9 s, sys: 965 ms, total: 3.86 s
# Wall time: 5min 46s

# %%
print(f'Test Embedding Size: {len(test_embeddings.features)}')
# Out:
# Test Embedding Size: 1510

# %%
testing_projection_df = df_for_projection(test_learn.data, train_set=False)
testing_projection_df.head()
# Out:
#                                             img_path      label  label_id
# 0  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 1  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 2  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 3  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 4  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2

# %%
testing_projection_df = append_features(testing_projection_df, test_embeddings)
testing_projection_df.head()
# Out:
#                                             img_path  ...                                           img_repr
# 0  /content/drive/My Drive/fast_covid_net/data/te...  ...  [34.13835906982422, 57.652366638183594, 76.409...
# 1  /content/drive/My Drive/fast_covid_net/data/te...  ...  [53.74272918701172, -74.09703826904297, -80.13...
# 2  /content/drive/My Drive/fast_covid_net/data/te...  ...  [45.6312255859375, -122.59851837158203, -121.5...
# 3  /content/drive/My Drive/fast_covid_net/data/te...  ...  [37.421104431152344, -114.49655151367188, -111...
# 4  /content/drive/My Drive/fast_covid_net/data/te...  ...  [40.916385650634766, -97.33411407470703, -103....
#
# [5 rows x 4 columns]

# %%
testing_projection_df = project_data(testing_projection_df)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 1510 samples in 0.054s...
# [t-SNE] Computed neighbors for 1510 samples in 0.833s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1510
# [t-SNE] Computed conditional probabilities for sample 1510 / 1510
# [t-SNE] Mean sigma: 128.988606
# [t-SNE] Computed conditional probabilities in 0.185s
# [t-SNE] Iteration 50: error = 52.9606323, gradient norm = 0.0001787 (50 iterations in 2.262s)
# [t-SNE] Iteration 100: error = 52.1002884, gradient norm = 0.0001005 (50 iterations in 2.213s)
# [t-SNE] Iteration 150: error = 51.7868347, gradient norm = 0.0001328 (50 iterations in 2.179s)
# [t-SNE] Iteration 200: error = 51.7379646, gradient norm = 0.0000586 (50 iterations in 2.175s)
# [t-SNE] Iteration 250: error = 51.7797089, gradient norm = 0.0000540 (50 iterations in 2.180s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.779709
# [t-SNE] Iteration 300: error = 1.7565579, gradient norm = 0.0000642 (50 iterations in 2.189s)
# [t-SNE] Iteration 350: error = 1.6981336, gradient norm = 0.0000434 (50 iterations in 2.172s)
# [t-SNE] Iteration 400: error = 1.6425790, gradient norm = 0.0000317 (50 iterations in 2.192s)
# [t-SNE] Iteration 450: error = 1.5943569, gradient norm = 0.0000245 (50 iterations in 2.188s)
# [t-SNE] Iteration 500: error = 1.5528456, gradient norm = 0.0000197 (50 iterations in 2.199s)
# [t-SNE] KL divergence after 500 iterations: 1.552846

# %%
#Visualize Img Distribution in 3 Dimensions
testing_projection_df.to_parquet('similar_images')
px.scatter_3d(testing_projection_df, 
              x='tsne1', 
              y='tsne2', 
              z='tsne3', 
              color='label', 
              title="Test Set Distribution - Scatter Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67f4bd29-9943-4803-a2b3-c01ce2dfdcb1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67f4bd29-9943-4803-a2b3-c01ce2dfdcb1")) {
#                     Plotly.newPlot(
#                         '67f4bd29-9943-4803-a2b3-c01ce2dfdcb1',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "label=pneumonia<br>tsne1=%{x}<br>tsne2=%{y}<br>tsne3=%{z}", "legendgroup": "label=pneumonia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "label=pneumonia", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1822.470947265625, -2386.759765625, -2475.1142578125, -2462.335693359375, -2387.419189453125, -2122.79345703125, -2232.947509765625, -2084.986083984375, -2156.190673828125, -1847.7603759765625, -2244.86572265625, 77.046142578125, -2296.064697265625, -2195.63134765625, -2219.323486328125, -2392.07421875, -1635.4710693359375, -1973.6158447265625, -2303.888671875, -2394.701904296875, -2094.76220703125, -2050.680908203125, -2139.870849609375, -2294.984375, -2216.59912109375, -2266.83935546875, -1952.8057861328125, -2121.749755859375, -2110.919921875, -2123.564208984375, -2109.687255859375, -2161.220947265625, -2015.11962890625, -2290.357177734375, -2209.8896484375, -1609.372314453125, -2079.890380859375, -2249.3330078125, -1645.515380859375, -1562.906982421875, -1083.368896484375, -1639.0009765625, -2045.362548828125, -2070.934814453125, -2224.009765625, -2139.1240234375, -2224.786865234375, -2019.0970458984375, -2073.171630859375, -2320.93212890625, -1844.73486328125, -1829.73681640625, -2120.0947265625, -2363.167236328125, -2397.05126953125, -2281.251220703125, -1924.1077880859375, -2016.4498291015625, -2181.9736328125, -2025.6689453125, -2239.210205078125, -1443.6859130859375, -2176.521728515625, -2156.666015625, -1834.8802490234375, -2108.290283203125, -2112.85986328125, -2332.630859375, -2250.5927734375, -1353.3604736328125, -2042.2733154296875, -2260.35302734375, -1990.5748291015625, -2285.6201171875, -2195.15673828125, -2220.870361328125, -2125.232421875, -2219.9560546875, -2304.1171875, -2122.13134765625, -2113.680419921875, -2131.05322265625, -1971.28857421875, -2283.71630859375, -2126.048583984375, -1415.3511962890625, -2257.6279296875, -2177.9873046875, -2058.714599609375, -457.4630126953125, -2166.20166015625, -2184.4267578125, -2065.589111328125, -1905.9974365234375, -2209.68896484375, -1699.6334228515625, -2125.952392578125, -1839.5224609375, -931.80908203125, -1451.399169921875, -2139.56396484375, -2369.54052734375, -2176.0205078125, -2242.231689453125, -2101.474853515625, -2281.138671875, -1568.8997802734375, -2081.125244140625, -1976.8497314453125, -2402.427734375, -2241.24658203125, -2170.956787109375, -2071.17822265625, -1778.3106689453125, -2282.47412109375, -1951.9324951171875, -2091.79736328125, -2167.7421875, -1984.071533203125, -2116.9853515625, -2498.82080078125, -2172.939697265625, -2039.5106201171875, -1564.3524169921875, -1880.2591552734375, -2180.2255859375, -2210.230712890625, -2247.00439453125, -2416.549072265625, -2363.972900390625, -2170.66796875, -1963.2777099609375, -2293.8759765625, -2218.152099609375, -2160.736328125, -1990.2919921875, -2347.165283203125, -2285.337890625, -1921.152099609375, -1209.990966796875, -1949.40966796875, -2180.71875, -1221.965087890625, -1975.2713623046875, -1733.7225341796875, -2107.028076171875, -2066.22021484375, -2171.03466796875, -2358.35986328125, -2034.7071533203125, -2159.929931640625, -2131.55078125, -2166.394287109375, -2212.425537109375, -2325.742919921875, -2250.35986328125, -2105.724609375, -2097.17724609375, -2146.514892578125, -2102.1640625, -2290.944580078125, -2231.041259765625, -2060.12255859375, -2104.090576171875, -2128.835693359375, -2145.313232421875, -2133.71630859375, -2236.29248046875, -2333.81591796875, -2344.892822265625, -2305.61181640625, -2140.16796875, -2281.247802734375, -2277.97265625, -2249.385498046875, -2259.474609375, -2410.265380859375, -1751.0322265625, -1878.6383056640625, -2222.789306640625, -2212.646728515625, -2330.80810546875, -2224.508544921875, -2195.156982421875, -1807.244873046875, -2175.84326171875, -2340.24951171875, -2074.261474609375, -2365.562744140625, -1957.387939453125, -2180.195068359 ...

# %%
testing_projection_df.describe()
# Out:
#           label_id         tsne1        tsne2        tsne3
# count  1510.000000   1510.000000  1510.000000  1510.000000
# mean      1.372848      0.002124    -0.001695     0.005526
# std       0.524475   3149.479492   964.519226   351.959106
# min       0.000000  -2498.820801 -1697.828613  -965.532471
# 25%       1.000000  -2113.283569  -859.792603  -225.206989
# 50%       1.000000  -1070.246277  -228.154709    -1.463618
# 75%       2.000000    590.081863   842.952286   210.419998
# max       2.000000  16454.212891  2929.210205  1950.315063

# %% [markdown]
# ### Inference Test Results

# %%
#store rows/diagonal entries of confusion matrics to tabulate metrics
test_interp = ClassificationInterpretation.from_learner(test_learn)
losses,idxs = test_interp.top_losses()
len(test_data.test_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
test_interp.plot_confusion_matrix(figsize=(8,8), dpi=60)

# %%
test_interp.most_confused(min_val=2)
# Out:
# [('normal', 'pneumonia', 36),
#  ('pneumonia', 'normal', 29),
#  ('COVID-19', 'normal', 2)]

# %%
test_conf_matrix = test_interp.confusion_matrix()
inference_metrics = get_metrics(test_conf_matrix)
print(inference_metrics)
# Out:
# [29, 1, 1481, 2, 849, 31, 661, 36, 564, 36, 946, 30]

# %%
#Precision for each class 
test_covid_precision = inference_metrics[0]/(inference_metrics[0]+inference_metrics[1])
test_norm_precision = inference_metrics[4]/(inference_metrics[4]+inference_metrics[5])
test_pneum_precision = inference_metrics[8]/(inference_metrics[8]+inference_metrics[9])

test_precision_scores = {
    "COVID-19": test_covid_precision,
    "NORMAL": test_norm_precision,
    "PNEUMONIA": test_pneum_precision
}

test_precision_scores = pd.DataFrame(test_precision_scores, 
                                      columns=train_precision_scores.keys(), 
                                      index=[0])
print("Precision Scores:")
test_precision_scores
# Out:
# Precision Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.966667  0.964773       0.94

# %%
#Recall for each class 
test_covid_recall = inference_metrics[0]/(inference_metrics[0]+inference_metrics[3])
test_norm_recall = inference_metrics[4]/(inference_metrics[4]+inference_metrics[7])
test_pneum_recall = inference_metrics[8]/(inference_metrics[8]+inference_metrics[11])

test_sensitivity_scores = {
    "COVID-19": test_covid_recall, 
    "NORMAL": test_norm_recall,
    "PNEUMONIA": test_pneum_recall
}

test_sensitivity_scores = pd.DataFrame(test_sensitivity_scores, 
                         columns=test_sensitivity_scores.keys(), 
                         index=[0])
print("Sensitivity Scores:")
test_sensitivity_scores
# Out:
# Sensitivity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.935484  0.959322   0.949495

# %%
#F1 Score for each class 
test_covid_f1 = 2*(test_covid_precision*test_covid_recall)/(test_covid_precision+test_covid_recall)
test_norm_f1 = 2 * (test_norm_precision*test_norm_recall)/(test_norm_precision + test_norm_recall)
test_pneum_f1 = 2 * (test_pneum_precision*test_pneum_recall)/(test_pneum_precision+test_pneum_recall)

test_f1_scores = {
    "COVID-19": test_covid_f1,
    "NORMAL": test_norm_f1,
    "PNEUMONIA": test_pneum_f1
}

test_f1_scores = pd.DataFrame(test_f1_scores, 
                         columns=test_f1_scores.keys(), 
                         index=[0])
print("F1 Scores:")
test_f1_scores
# Out:
# F1 Scores:
#    COVID-19   NORMAL  PNEUMONIA
# 0   0.95082  0.96204   0.944724

# %%
#Specificity for each class 
test_covid_specificity = inference_metrics[2]/(inference_metrics[2]+inference_metrics[1])
test_norm_specificity = inference_metrics[6]/(inference_metrics[6]+inference_metrics[5])
test_pneum_specificity = inference_metrics[10]/(inference_metrics[10]+inference_metrics[9])

test_specificity_scores = {"COVID-19": test_covid_specificity, 
                      "NORMAL": test_norm_specificity, 
                      "PNEUMONIA": test_pneum_specificity}
                      
test_specificity_df = pd.DataFrame(test_specificity_scores, 
                              columns=test_specificity_scores.keys(), 
                              index=[0])
print("Specificity Scores:")
test_specificity_df
# Out:
# Specificity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.999325  0.955202    0.96334

# %%
accuracy(*test_learn.TTA())
# Out:
# tensor(0.9576)

# %%
#Compress model files for use in FastAPI
import shutil
shutil.make_archive('models', 'zip', 'models')
# Out:
# '/content/models.zip'
