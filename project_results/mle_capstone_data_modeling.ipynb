# %% [markdown]
# #Udacity MLE Nanodegree Capstone - Training
# Light-weight Data ModeEfficientnet and Fast.ai for Chest X-Ray (CXR) classification task; light-weight modeling for detecting upper-respitorty viral infenctions from Chests.

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ###Environment Setup:

# %%
# !pip install pthflops
# !pip install plotly_express
# !pip install pytorchcv
# Out:
# Collecting pthflops
#   Downloading https://files.pythonhosted.org/packages/aa/ba/01ea6b85cb7ee48cf12b6bf08104d5806a9304ade9bb4643dfad9bcdb024/pthflops-0.2.2.tar.gz
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from pthflops) (1.5.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch->pthflops) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->pthflops) (0.16.0)
# Building wheels for collected packages: pthflops
#   Building wheel for pthflops (setup.py) ... done
#   Created wheel for pthflops: filename=pthflops-0.2.2-cp36-none-any.whl size=5108 sha256=c7d1e57fa69412be7e54441aff723ee09c5e75a87c776ce9aa1e2c89dd26a969
#   Stored in directory: /root/.cache/pip/wheels/f8/c8/14/8a85a906c6eba9ed3e1c331c4f66dc8c43a7b4953a88e04397
# Successfully built pthflops
# Installing collected packages: pthflops
# Successfully installed pthflops-0.2.2
# Collecting plotly_express
#   Downloading https://files.pythonhosted.org/packages/d4/d6/8a2906f51e073a4be80cab35cfa10e7a34853e60f3ed5304ac470852a08d/plotly_express-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.0.4)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.18.5)
# Requirement already satisfied: plotly>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (4.4.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (0.10.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.6/dist-packages (from plotly_express) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.0->plotly_express) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5->plotly_express) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=4.1.0->plotly_express) (1.3.3)
# Installing collected packages: plotly-express
# Successfully installed plotly-express-0.4.1
# Collecting pytorchcv
#   Downloading https://files.pythonhosted.org/packages/93/be/0bcd80dfc0d64e75ceb67836385402fece3c3b964c349172a21358813b25/pytorchcv-0.0.58-py2.py3-none-any.whl (435kB)
#      |████████████████████████████████| 440kB 2.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from pytorchcv) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2020.4.5.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->pytorchcv) (1.24.3)
# Installing collected packages: pytorchcv
# Successfully installed pytorchcv-0.0.58

# %%
with open('/content/common.py','r') as writer_file:
    contents_to_write = writer_file.read()
with open('/usr/local/lib/python3.6/dist-packages/pytorchcv/models/common.py' ,'w') as file_to_overwrite:
    file_to_overwrite.write(contents_to_write)
    print("Restart Notebook/Kernel")
# Out:
# Restart Notebook/Kernel

# %% [markdown]
# ###Import Packages:

# %%
#utils
from __future__ import print_function
from __future__ import division
import os
import json
import zipfile
import shutil 

#
from sklearn.manifold import TSNE
import plotly_express as px

#data science/ml
from pytorchcv.model_provider import get_model as ptcv_get_model
import fastai
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.callbacks import HookCallback
from fastai.callbacks.tracker import EarlyStoppingCallback
from fastai.callbacks.tracker import SaveModelCallback
from fastai.callbacks.tracker import ReduceLROnPlateauCallback
  
import torch
import torch.utils.data
import torchvision
from torchvision.utils import make_grid
import numpy as np
import tracemalloc
from pthflops import count_ops

import warnings
warnings.filterwarnings('ignore')

# %%
print("Using fast.ai version: ", fastai.__version__)
# Out:
# Using fast.ai version:  1.0.61

# %% [markdown]
# ### Hardware Specs

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print("Hardware Specs: ")
  print(gpu_info)
# Out:
# Hardware Specs:
# Fri Jun 19 04:57:26 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    30W / 250W |     10MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
"""
If using data download generated from preprocessing, 
upload zip file (e.g., data.zip), .csv label files,  
run this cell, and skip the next cell.
"""
#data_zip = zipfile.ZipFile(<path to data zip file >)
#data_zip.extractall()
#path = Path(< path to parent dir of extracted 'data' folder >)
#path.ls()

# %%
#directory with data and labels (in .csv format for this project)
path = Path("/content/drive/My Drive/fast_covid_net/")
path.ls()
# Out:
# [PosixPath('/content/drive/My Drive/fast_covid_net/data'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/train_split_v3.csv'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/test_split_v3.csv'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/extras'),
#  PosixPath('/content/drive/My Drive/fast_covid_net/e-covidnet.pkl')]

# %% [markdown]
# ### Creating Fastai Torch Dataloaders

# %%
#Basic hyperparameters 
bs = 16
size = 240

#Transforms to apply
tfms = [(contrast(scale=(1.5, 1.85), p=0.7),
         crop_pad(), 
         *zoom_crop(scale=(1.15,1.5), do_rand=True, p=.2)), ()]

# %%
#label df
print("Labeled Training Data; pandas DataFrame (DF)")
labels = pd.read_csv(path/'train_split_v3.csv', header='infer')
labels.head()
# Out:
# Labeled Training Data; pandas DataFrame (DF)
#   patient_id  ... label_short
# 0          3  ...          PA
# 1          3  ...          PA
# 2          3  ...          PA
# 3          7  ...          PA
# 4          7  ...          PA
#
# [5 rows x 4 columns]

# %% [markdown]
# Generate **ImageDataBunch** for training.
# Docs: https://docs.fast.ai/vision.data.html#ImageDataBunch

# %%
def random_seed(seed_value):
    import random 
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

# %%
#Create ImageDataBunch from labels DF
#random_seed(38)
data = ImageDataBunch.from_df(path, 
                              labels, 
                              folder='data/train', 
                              ds_tfms=tfms, 
                              fn_col=1, 
                              label_col=2, 
                              size=size, 
                              bs=bs)

data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (10904 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net;
#
# Valid: LabelList (2726 items)
# x: ImageList
# Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240),Image (3, 240, 240)
# y: CategoryList
# normal,normal,pneumonia,pneumonia,normal
# Path: /content/drive/My Drive/fast_covid_net;
#
# Test: None

# %%
print("Sample Batch, Transformed")
data.show_batch(rows=3, figsize=(10, 10))
# Out:
# Sample Batch, Transformed

# %%
# From: https://github.com/ufoym/imbalanced-dataset-sampler/blob/master/torchsampler/imbalanced.py
class ImbalancedDatasetSampler(torch.utils.data.sampler.Sampler):
    """Samples elements randomly from a given list of indices for imbalanced dataset
    Args:
        - indices (list, optional): a list of indices
        - num_samples (int, optional): number of samples to draw
    """
    def __init__(self, dataset, indices=None, num_samples=None):
                
        # if indices is not provided, 
        # all elements in the dataset will be considered
        self.indices = list(range(len(dataset))) \
            if indices is None else indices
            
        # if num_samples is not provided, 
        # draw `len(indices)` samples in each iteration
        self.num_samples = len(self.indices) \
            if num_samples is None else num_samples
            
        # distribution of classes in the dataset 
        label_to_count = {}
        for idx in self.indices:
            label = self._get_label(dataset, idx)
            for l in label:
                if l in label_to_count:
                    label_to_count[l] += 1
                else: label_to_count[l]=1
        
        # weight for each sample
        weights = [1.0 / min([label_to_count[l] for l in self._get_label(dataset, idx)])
                   for idx in self.indices]
        self.weights = torch.DoubleTensor(weights)

    def _get_label(self, dataset, idx):
        return dataset.y[idx].obj #for category obj
                
    def __iter__(self):
        return (self.indices[i] for i in torch.multinomial(
            self.weights, self.num_samples, replacement=True))

    def __len__(self):
        return self.num_samples

# %%
def get_data(sz, tfs, batch=16, workers=4):
  """
  Automates the instantiation of DataLoaders with oversampling of 
  minority class. 
  Args: 
    - sz --> type:int --> img size.
    - tfms --> type:List --> transforms. 
    - batch --> type:int, default=8 --> batch size. 
    - workers --> type:int, default=4 --> number of workers for each dataloader   
  """
  data = ImageDataBunch.from_df(path, 
                                labels, 
                                folder='data/train', 
                                ds_tfms=tfs, fn_col=1, 
                                label_col=2, 
                                size=sz,
                                resize_method=ResizeMethod.SQUISH, 
                                bs=bs)
  data.normalize(imagenet_stats)
  train_ds, val_ds = data.train_ds, data.valid_ds
  sampler = ImbalancedDatasetSampler(train_ds)
  train_dl = DataLoader(train_ds, bs, sampler=sampler, num_workers=workers)
  val_dl = DataLoader(val_ds, 2*bs, False, num_workers=workers)
  
  data = ImageDataBunch(train_dl=train_dl, 
                        valid_dl=val_dl).normalize(imagenet_stats)
  return data

# %%
data = get_data(sz=size, tfs=tfms)

# %%
print("Sample Batch, Transformed and Resampled")
data.show_batch(rows=3, figsize=(10, 10))
# Out:
# Sample Batch, Transformed and Resampled

# %%
#Labels
print(f'Labels for this Task: {data.classes}')
# Out:
# Labels for this Task: ['COVID-19', 'normal', 'pneumonia']

# %%
effnet_features = ptcv_get_model("efficientnet_b1", pretrained=True).features
# Out:
# Downloading /root/.torch/models/efficientnet_b1-0638-ac77bcd7.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.376/efficientnet_b1-0638-ac77bcd7.pth.zip...

# %%
effnet_features = ptcv_get_model("efficientnet_b1", pretrained=True).features

# %%
def arch_summary(arch):
  """
  A helper for listing the sequential layer groups of the network
  Args:
    - arch --> type:nn.ModuleList --> A list of modules.
  https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/utils.py
  """
  model = arch(False)
  tot = 0
  for i, l in enumerate(model.children()):
      n_layers = len(flatten_model(l))
      tot += n_layers
      print(f'({i}) {l.__class__.__name__:<12}: {n_layers:<4}layers (total: {tot})')


def get_groups(m, layer_groups):
  """
  a helper method for listing the layer groups after the layer cuts have been 
  determined for discriminative learning rates.
  Args:
    - m --> type:nn.ModuleList/nn.Sequential --> A list of modules.
    - layer_groups --> type:list --> List of layers grouped by split defined in 
    Learner class. 
  """
  group_indices = [len(g) for g in layer_groups]
  curr_i = 0
  group = []
  for layer in model:
      group_indices[curr_i] -= len(flatten_model(layer))
      group.append(layer.__class__.__name__)
      if group_indices[curr_i] == 0:
          curr_i += 1
          print(f'Group {curr_i}:', group)   
          group = []

# %%
print("Model Blocks:")
arch_summary(lambda _: effnet_features)
# Out:
# Model Blocks:
# (0) EffiInitBlock: 3   layers (total: 3)
# (1) Sequential  : 20  layers (total: 23)
# (2) Sequential  : 39  layers (total: 62)
# (3) Sequential  : 39  layers (total: 101)
# (4) Sequential  : 104 layers (total: 205)
# (5) Sequential  : 91  layers (total: 296)
# (6) ConvBlock   : 3   layers (total: 299)
# (7) AdaptiveAvgPool2d: 1   layers (total: 300)

# %%
print("Model Blocks (Detailed):")
for i in range(len(effnet_features) - 1):
    print(f'---------({i})---------')
    arch_summary(lambda _: effnet_features[i])
# Out:
# Model Blocks (Detailed):
# ---------(0)---------
# (0) ConvBlock   : 3   layers (total: 3)
# ---------(1)---------
# (0) EffiDwsConvUnit: 10  layers (total: 10)
# (1) EffiDwsConvUnit: 10  layers (total: 20)
# ---------(2)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# ---------(3)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# ---------(4)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# (3) EffiInvResUnit: 13  layers (total: 52)
# (4) EffiInvResUnit: 13  layers (total: 65)
# (5) EffiInvResUnit: 13  layers (total: 78)
# (6) EffiInvResUnit: 13  layers (total: 91)
# (7) EffiInvResUnit: 13  layers (total: 104)
# ---------(5)---------
# (0) EffiInvResUnit: 13  layers (total: 13)
# (1) EffiInvResUnit: 13  layers (total: 26)
# (2) EffiInvResUnit: 13  layers (total: 39)
# (3) EffiInvResUnit: 13  layers (total: 52)
# (4) EffiInvResUnit: 13  layers (total: 65)
# (5) EffiInvResUnit: 13  layers (total: 78)
# (6) EffiInvResUnit: 13  layers (total: 91)
# ---------(6)---------
# (0) Conv2d      : 1   layers (total: 1)
# (1) BatchNorm2d : 1   layers (total: 2)
# (2) Swish       : 1   layers (total: 3)

# %%
def efficientnet_b1(pretrained=True):
  """
  Returns efficientnet-b1 feature extraction layers, using pytorchcv's
  ptcv_get_model helper method.
  Args:
    pretrained --> type:bool (default: True) 
  """
  return ptcv_get_model("efficientnet_b1", pretrained=pretrained).features

#Fastai Learner (Model with built-in Training Tools)
def get_learner(train_data):
  """
  Generates a fastai Learner with passed fastai ImageDataBunch data loaders and 
  feature extraction layers from a pretrained EfficientNet-b1 network. 
  Uses Half-Tensor Precision.
  Args:
    train_data --> type:ImageDataBunch  
  """
  learn = cnn_learner(train_data, 
                      efficientnet_b1, 
                      metrics=[error_rate, accuracy], 
                      callback_fns=[ShowGraph])
  return learn

# %%
#pretrained on ImageNet dataset - weights provided by pytorchcv library 
learn = get_learner(data)
print(learn.summary())
print("Loss Function: ", learn.loss_func)
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [32, 120, 120]       864        False
# ______________________________________________________________________
# BatchNorm2d          [32, 120, 120]       64         True
# ______________________________________________________________________
# Swish                [32, 120, 120]       0          False
# ______________________________________________________________________
# Conv2d               [32, 120, 120]       288        False
# ______________________________________________________________________
# BatchNorm2d          [32, 120, 120]       64         True
# ______________________________________________________________________
# Swish                [32, 120, 120]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [8, 1, 1]            264        False
# ______________________________________________________________________
# Swish                [8, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [32, 1, 1]           288        False
# ______________________________________________________________________
# Sigmoid              [32, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       512        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       144        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Swish                [16, 120, 120]       0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [4, 1, 1]            68         False
# ______________________________________________________________________
# Swish                [4, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [16, 1, 1]           80         False
# ______________________________________________________________________
# Sigmoid              [16, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [16, 120, 120]       256        False
# ______________________________________________________________________
# BatchNorm2d          [16, 120, 120]       32         True
# ______________________________________________________________________
# Conv2d               [96, 120, 120]       1,536      False
# ______________________________________________________________________
# BatchNorm2d          [96, 120, 120]       192        True
# ______________________________________________________________________
# Swish                [96, 120, 120]       0          False
# ______________________________________________________________________
# Conv2d               [96, 60, 60]         864        False
# ______________________________________________________________________
# BatchNorm2d          [96, 60, 60]         192        True
# ______________________________________________________________________
# Swish                [96, 60, 60]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [96, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [4, 1, 1]            388        False
# ______________________________________________________________________
# Swish                [4, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [96, 1, 1]           480        False
# ______________________________________________________________________
# Sigmoid              [96, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         2,304      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        1,296      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         3,456      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        1,296      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [24, 60, 60]         3,456      False
# ______________________________________________________________________
# BatchNorm2d          [24, 60, 60]         48         True
# ______________________________________________________________________
# Conv2d               [144, 60, 60]        3,456      False
# ______________________________________________________________________
# BatchNorm2d          [144, 60, 60]        288        True
# ______________________________________________________________________
# Swish                [144, 60, 60]        0          False
# ______________________________________________________________________
# Conv2d               [144, 30, 30]        3,600      False
# ______________________________________________________________________
# BatchNorm2d          [144, 30, 30]        288        True
# ______________________________________________________________________
# Swish                [144, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [6, 1, 1]            870        False
# ______________________________________________________________________
# Swish                [6, 1, 1]            0          False
# ______________________________________________________________________
# Conv2d               [144, 1, 1]          1,008      False
# ______________________________________________________________________
# Sigmoid              [144, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         5,760      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        6,000      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         9,600      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        6,000      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [40, 30, 30]         9,600      False
# ______________________________________________________________________
# BatchNorm2d          [40, 30, 30]         80         True
# ______________________________________________________________________
# Conv2d               [240, 30, 30]        9,600      False
# ______________________________________________________________________
# BatchNorm2d          [240, 30, 30]        480        True
# ______________________________________________________________________
# Swish                [240, 30, 30]        0          False
# ______________________________________________________________________
# Conv2d               [240, 15, 15]        2,160      False
# ______________________________________________________________________
# BatchNorm2d          [240, 15, 15]        480        True
# ______________________________________________________________________
# Swish                [240, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [10, 1, 1]           2,410      False
# ______________________________________________________________________
# Swish                [10, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [240, 1, 1]          2,640      False
# ______________________________________________________________________
# Sigmoid              [240, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         19,200     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        4,320      False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [80, 15, 15]         38,400     False
# ______________________________________________________________________
# BatchNorm2d          [80, 15, 15]         160        True
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        38,400     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [480, 15, 15]        12,000     False
# ______________________________________________________________________
# BatchNorm2d          [480, 15, 15]        960        True
# ______________________________________________________________________
# Swish                [480, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [20, 1, 1]           9,620      False
# ______________________________________________________________________
# Swish                [20, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [480, 1, 1]          10,080     False
# ______________________________________________________________________
# Sigmoid              [480, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        53,760     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [112, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [112, 15, 15]        224        True
# ______________________________________________________________________
# Conv2d               [672, 15, 15]        75,264     False
# ______________________________________________________________________
# BatchNorm2d          [672, 15, 15]        1,344      True
# ______________________________________________________________________
# Swish                [672, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [672, 8, 8]          16,800     False
# ______________________________________________________________________
# BatchNorm2d          [672, 8, 8]          1,344      True
# ______________________________________________________________________
# Swish                [672, 8, 8]          0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [28, 1, 1]           18,844     False
# ______________________________________________________________________
# Swish                [28, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [672, 1, 1]          19,488     False
# ______________________________________________________________________
# Sigmoid              [672, 1, 1]          0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          129,024    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         28,800     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [192, 8, 8]          221,184    False
# ______________________________________________________________________
# BatchNorm2d          [192, 8, 8]          384        True
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         221,184    False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1152, 8, 8]         10,368     False
# ______________________________________________________________________
# BatchNorm2d          [1152, 8, 8]         2,304      True
# ______________________________________________________________________
# Swish                [1152, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [48, 1, 1]           55,344     False
# ______________________________________________________________________
# Swish                [48, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1152, 1, 1]         56,448     False
# ______________________________________________________________________
# Sigmoid              [1152, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [320, 8, 8]          368,640    False
# ______________________________________________________________________
# BatchNorm2d          [320, 8, 8]          640        True
# ______________________________________________________________________
# Conv2d               [1920, 8, 8]         614,400    False
# ______________________________________________________________________
# BatchNorm2d          [1920, 8, 8]         3,840      True
# ______________________________________________________________________
# Swish                [1920, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [1920, 8, 8]         17,280     False
# ______________________________________________________________________
# BatchNorm2d          [1920, 8, 8]         3,840      True
# ______________________________________________________________________
# Swish                [1920, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1920, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [80, 1, 1]           153,680    False
# ______________________________________________________________________
# Swish                [80, 1, 1]           0          False
# ______________________________________________________________________
# Conv2d               [1920, 1, 1]         155,520    False
# ______________________________________________________________________
# Sigmoid              [1920, 1, 1]         0          False
# ______________________________________________________________________
# Conv2d               [320, 8, 8]          614,400    False
# ______________________________________________________________________
# BatchNorm2d          [320, 8, 8]          640        True
# ______________________________________________________________________
# Conv2d               [1280, 8, 8]         409,600    False
# ______________________________________________________________________
# BatchNorm2d          [1280, 8, 8]         2,560      True
# ______________________________________________________________________
# Swish                [1280, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [1280, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [1280, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [2560]               0          False
# ______________________________________________________________________
# BatchNorm1d          [2560]               5,120      True
# ______________________________________________________________________
# Dropout              [2560]               0          False
# ______________________________________________________________________
# Linear               [512]                1,311,232  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [3]                  1,539      True
# ______________________________________________________________________
#
# Total params: 7,832,099
# Total trainable params: 1,380,963
# Total non-trainable params: 6,451,136
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#
# Loss Function:  FlattenedLoss of CrossEntropyLoss()

# %%
gc.collect()
# Out:
# 36146

# %%
#https://www.kaggle.com/qitvision/a-complete-ml-pipeline-fast-ai/comments
def wd_grid_search(data, decay_list, frozen=False, plot_y_min=2.00, 
                   plot_y_max=3.80, plot_x_min=1e-6, plot_x_max=1e+00):
  """
  Wraps fastai Learner.Recorder.find_lr() method, loops through decay_list of
  weight decay values and visualizes performance on a test run to help select 
  the optimal amount of decay:
  Args:
    - data --> type:ImageDataBunch 
    - decay_list -> type:List[] -> list of weight decay values to test
    - frozen -> type:bool -> fine-tuning clasifier (True) or entire network (False)
    - plot_y_min, plot_y_max, plot_x_min, plot_x_max -> type:float
      -> ranges for axis of final chart on performance 
  """
  lrs = []
  losses = []
  wds = []

  def reset_learner():
    if frozen:
      learner = get_learner(data)
      learner.freeze()
      return learner
    else:
      learner = get_learner(data)
      learner.unfreeze()
      return learner

  learner = reset_learner()

  #Search w/o weight decay (baseline)
  learner.lr_find(num_it=300)
  lrs.append(learner.recorder.lrs)
  losses.append(learner.recorder.losses)
  wds.append('None')
  learner = reset_learner()

  #for each weight decay value, search for best learning rate 
  for item in decay_list: 
    learner.lr_find(num_it=300, wd=item)
    lrs.append(learner.recorder.lrs)
    losses.append(learner.recorder.losses)
    wds.append(str(item))
    reset_learner()

  #Plot losses for wd values over learning rates  
  _, ax = plt.subplots(1,1)
  min_y = plot_y_min
  max_y = plot_y_max
  min_x = plot_x_min
  max_x = plot_x_max
  for i in range(len(losses)):
    ax.plot(lrs[i], losses[i])
    min_y = min(np.isfinite(np.asarray(losses[i])).min(), min_y)
  ax.set_ylabel("Loss")
  ax.set_xlabel("Learning Rate")
  ax.set_xscale('log')
  #ax ranges may need some tuning with different model architectures 
  ax.set_xlim((min_x, max_x))
  ax.set_ylim((min_y, max_y))
  ax.legend(wds)
  ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%.0e'))

# %%
class TraceMallocMultiColMetric(LearnerCallback):
  """
  #Fastai Learner Callback to measures peak RAM usage during each epoch.
  Callbacks and Custom Metrics, Docs: #https://docs.fast.ai/metrics.html#Creating-your-own-metric
  """
  _order=-20 # Needs to run before the recorder
  def __init__(self, learn):
    super().__init__(learn)
    self.train_max = 0

  def on_train_begin(self, **kwargs):
    self.learn.recorder.add_metric_names(['used', 'max_used', 'peak'])
            
  def on_batch_end(self, train, **kwargs):
    # track max memory usage during the train phase
    if train:
      current, peak =  tracemalloc.get_traced_memory()
      self.train_max = max(self.train_max, current)
        
  def on_epoch_begin(self, **kwargs):
      tracemalloc.start()

  def on_epoch_end(self, last_metrics, **kwargs):
      current, peak =  tracemalloc.get_traced_memory()
      tracemalloc.stop()
      return add_metrics(last_metrics, [current, self.train_max, peak])

# %% [markdown]
# ### Stage 1:

# %%
gc.collect()
wd_grid_search(learn.data, 
               [2e-1, 2e-2, 2e-3, 2e-4], 
               frozen=False,
               plot_x_max=float(1e-1), 
               plot_y_min=1.00, 
               plot_y_max=2.25)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='245' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.92% [245/682 01:54<03:24 4.8587]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='251' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.80% [251/682 01:54<03:17 4.5634]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='247' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.22% [247/682 01:56<03:25 4.6446]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='243' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.63% [243/682 01:53<03:25 4.4640]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='243' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.63% [243/682 01:56<03:29 4.5986]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#garbage collection for gpu memory 
gc.collect()
# Out:
# 7254

# %%
#fit unfrozen, using one-cycle policy:
#appends callback to learners callback list for this run
#learn.callbacks.append(TraceMallocMultiColMetric(learn))
learn.unfreeze() 
learn.fit_one_cycle(6, slice(5e-3), wd=2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.398696</td>
#       <td>0.355289</td>
#       <td>0.099780</td>
#       <td>0.900220</td>
#       <td>06:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.430214</td>
#       <td>0.289148</td>
#       <td>0.133529</td>
#       <td>0.866471</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.320426</td>
#       <td>0.246866</td>
#       <td>0.083639</td>
#       <td>0.916361</td>
#       <td>06:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.194360</td>
#       <td>0.188003</td>
#       <td>0.059795</td>
#       <td>0.940205</td>
#       <td>06:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.117777</td>
#       <td>0.156498</td>
#       <td>0.056126</td>
#       <td>0.943874</td>
#       <td>06:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.112121</td>
#       <td>0.156451</td>
#       <td>0.057594</td>
#       <td>0.942406</td>
#       <td>06:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Save checkpoint
learn.save('eff_covid_1')

# %%
sample = torch.randn(1, 3, 240, 240).cuda() 
print("FLOPs Count")
count_ops(learn.model, sample, )
# Out:
# FLOPs Count
# Operation                   OPS
# --------------------------  ---------
# /onnx::Conv                 12902400
# /onnx::BatchNormalization   921600
# /onnx::Conv                 4147200
# /onnx::BatchNormalization   921600
# /onnx::GlobalAveragePool    460800
# /onnx::Conv                 256
# /onnx::Conv                 256
# /onnx::Mul                  460800
# /onnx::Conv                 7372800
# /onnx::BatchNormalization   460800
# /onnx::Conv                 2073600
# /onnx::BatchNormalization   460800
# /onnx::GlobalAveragePool    230400
# /onnx::Conv                 64
# /onnx::Conv                 64
# /onnx::Mul                  230400
# /onnx::Conv                 3686400
# /onnx::BatchNormalization   460800
# /onnx::Add                  230400
# /onnx::Conv                 22118400
# /onnx::BatchNormalization   2764800
# /onnx::Conv                 3110400
# /onnx::BatchNormalization   691200
# /onnx::GlobalAveragePool    345600
# /onnx::Conv                 384
# /onnx::Conv                 384
# /onnx::Mul                  345600
# /onnx::Conv                 8294400
# /onnx::BatchNormalization   172800
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 3240000
# /onnx::BatchNormalization   259200
# /onnx::GlobalAveragePool    129600
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  129600
# /onnx::Conv                 5184000
# /onnx::BatchNormalization   72000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 486000
# /onnx::BatchNormalization   108000
# /onnx::GlobalAveragePool    54000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  54000
# /onnx::Conv                 4320000
# /onnx::BatchNormalization   36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 2700000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 12096000
# /onnx::BatchNormalization   50400
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 1075200
# /onnx::BatchNormalization   86016
# /onnx::GlobalAveragePool    43008
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  43008
# /onnx::Conv                 8257536
# /onnx::BatchNormalization   24576
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 663552
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 23592960
# /onnx::BatchNormalization   40960
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   245760
# /onnx::Conv                 1105920
# /onnx::BatchNormalization   245760
# /onnx::GlobalAveragePool    122880
# /onnx::Conv                 153600
# /onnx::Conv                 153600
# /onnx::Mul                  122880
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   40960
# /onnx::Add                  20480
# /onnx::Conv                 26214400
# /onnx::BatchNormalization   163840
# /onnx::MaxPool              80640
# /onnx::GlobalAveragePool    81920
# /onnx::BatchNormalization   5120
# /onnx::Gemm                 1310720
# /onnx::Relu                 1024
# /onnx::BatchNormalization   1024
# /onnx::Gemm                 1536
# -------------------------   --------
# Input size: (1, 3, 240, 240)
# 718,097,040 FLOPs or approx. 0.72 GFLOPs
# (718097040,
#  [['/onnx::Conv', 12902400],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::Conv', 4147200],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::GlobalAveragePool', 460800],
#   ['/onnx::Conv', 256],
#   ['/onnx::Conv', 256],
#   ['/onnx::Mul', 460800],
#   ['/onnx::Conv', 7372800],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Conv', 2073600],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::GlobalAveragePool', 230400],
#   ['/onnx::Conv', 64],
#   ['/onnx::Conv', 64],
#   ['/onnx::Mul', 230400],
#   ['/onnx::Conv', 3686400],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Add', 230400],
#   ['/onnx::Conv', 22118400],
#   ['/onnx::BatchNormalization', 2764800],
#   ['/onnx::Conv', 3110400],
#   ['/onnx::BatchNormalization', 691200],
#   ['/onnx::GlobalAveragePool', 345600],
#   ['/onnx::Conv', 384],
#   ['/onnx::Conv', 384],
#   ['/onnx::Mul', 345600],
#   ['/onnx::Conv', 8294400],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 3240000],
#   ['/onnx::BatchNormalization', 259200],
#   ['/onnx::GlobalAveragePool', 129600],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 129600],
#   ['/onnx::Conv', 5184000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 486000],
#   ['/onnx::BatchNormalization', 108000],
#   ['/onnx::GlobalAveragePool', 54000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 54000],
#   ['/onnx::Conv', 4320000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 2700000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 12096000],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 1075200],
#   ['/onnx::BatchNormalization', 86016],
#   ['/onnx::GlobalAveragePool', 43008],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 43008],
#   ['/onnx::Conv', 8257536],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 663552],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 23592960],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::Conv', 1105920],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::GlobalAveragePool', 122880],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Mul', 122880],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Add', 20480],
#   ['/onnx::Conv', 26214400],
#   ['/onnx::BatchNormalization', 163840],
#   ['/onnx::MaxPool', 80640],
#   ['/onnx::GlobalAveragePool', 81920],
#   ['/onnx::BatchNormalization', 5120],
#   ['/onnx::Gemm', 1310720],
#   ['/onnx::Relu', 1024],
#   ['/onnx::BatchNormalization', 1024],
#   ['/onnx::Gemm', 1536]])

# %% [markdown]
# ### Stage 2:

# %%
gc.collect()
#random_seed(65)
data2 = get_data(300, tfms)
learn = get_learner(data2)
learn.load('eff_covid_1')
wd_grid_search(learn.data, 
               [2e-1, 2e-2, 2e-3, 2e-4], #hparam search
               frozen=True, 
               plot_x_max=float(1e-1), 
               plot_y_min=1.0,
               plot_y_max=2.25)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='250' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.66% [250/682 02:15<03:53 5.0695]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='255' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       37.39% [255/682 02:16<03:48 4.3971]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='246' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.07% [246/682 02:14<03:58 4.2820]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='250' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.66% [250/682 02:12<03:49 4.9564]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='247' class='' max='682' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       36.22% [247/682 02:13<03:54 4.7734]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#fit frozen, using one-cycle policy: 
gc.collect()
learn.callbacks.append(TraceMallocMultiColMetric(learn))
learn.freeze()
learn.fit_one_cycle(3, max_lr=slice(2e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>used</th>
#       <th>max_used</th>
#       <th>peak</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.188432</td>
#       <td>0.126464</td>
#       <td>0.047322</td>
#       <td>0.952678</td>
#       <td>287769</td>
#       <td>363498</td>
#       <td>383375</td>
#       <td>07:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.127815</td>
#       <td>0.133810</td>
#       <td>0.046222</td>
#       <td>0.953778</td>
#       <td>211449</td>
#       <td>363498</td>
#       <td>304535</td>
#       <td>07:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.144439</td>
#       <td>0.119820</td>
#       <td>0.042920</td>
#       <td>0.957080</td>
#       <td>205504</td>
#       <td>363498</td>
#       <td>299830</td>
#       <td>07:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Save checkpoint
learn.save('eff_covid_2')

# %%
print("FLOPs Count:")
count_ops(learn.model, sample,)
# Out:
# FLOPs Count:
# Operation                   OPS
# --------------------------  ---------
# /onnx::Conv                 12902400
# /onnx::BatchNormalization   921600
# /onnx::Conv                 4147200
# /onnx::BatchNormalization   921600
# /onnx::GlobalAveragePool    460800
# /onnx::Conv                 256
# /onnx::Conv                 256
# /onnx::Mul                  460800
# /onnx::Conv                 7372800
# /onnx::BatchNormalization   460800
# /onnx::Conv                 2073600
# /onnx::BatchNormalization   460800
# /onnx::GlobalAveragePool    230400
# /onnx::Conv                 64
# /onnx::Conv                 64
# /onnx::Mul                  230400
# /onnx::Conv                 3686400
# /onnx::BatchNormalization   460800
# /onnx::Add                  230400
# /onnx::Conv                 22118400
# /onnx::BatchNormalization   2764800
# /onnx::Conv                 3110400
# /onnx::BatchNormalization   691200
# /onnx::GlobalAveragePool    345600
# /onnx::Conv                 384
# /onnx::Conv                 384
# /onnx::Mul                  345600
# /onnx::Conv                 8294400
# /onnx::BatchNormalization   172800
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 4665600
# /onnx::BatchNormalization   1036800
# /onnx::GlobalAveragePool    518400
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  518400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   172800
# /onnx::Add                  86400
# /onnx::Conv                 12441600
# /onnx::BatchNormalization   1036800
# /onnx::Conv                 3240000
# /onnx::BatchNormalization   259200
# /onnx::GlobalAveragePool    129600
# /onnx::Conv                 864
# /onnx::Conv                 864
# /onnx::Mul                  129600
# /onnx::Conv                 5184000
# /onnx::BatchNormalization   72000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 5400000
# /onnx::BatchNormalization   432000
# /onnx::GlobalAveragePool    216000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  216000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   72000
# /onnx::Add                  36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   432000
# /onnx::Conv                 486000
# /onnx::BatchNormalization   108000
# /onnx::GlobalAveragePool    54000
# /onnx::Conv                 2400
# /onnx::Conv                 2400
# /onnx::Mul                  54000
# /onnx::Conv                 4320000
# /onnx::BatchNormalization   36000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 972000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   36000
# /onnx::Add                  18000
# /onnx::Conv                 8640000
# /onnx::BatchNormalization   216000
# /onnx::Conv                 2700000
# /onnx::BatchNormalization   216000
# /onnx::GlobalAveragePool    108000
# /onnx::Conv                 9600
# /onnx::Conv                 9600
# /onnx::Mul                  108000
# /onnx::Conv                 12096000
# /onnx::BatchNormalization   50400
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 3780000
# /onnx::BatchNormalization   302400
# /onnx::GlobalAveragePool    151200
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  151200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   50400
# /onnx::Add                  25200
# /onnx::Conv                 16934400
# /onnx::BatchNormalization   302400
# /onnx::Conv                 1075200
# /onnx::BatchNormalization   86016
# /onnx::GlobalAveragePool    43008
# /onnx::Conv                 18816
# /onnx::Conv                 18816
# /onnx::Mul                  43008
# /onnx::Conv                 8257536
# /onnx::BatchNormalization   24576
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 1843200
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   24576
# /onnx::Add                  12288
# /onnx::Conv                 14155776
# /onnx::BatchNormalization   147456
# /onnx::Conv                 663552
# /onnx::BatchNormalization   147456
# /onnx::GlobalAveragePool    73728
# /onnx::Conv                 55296
# /onnx::Conv                 55296
# /onnx::Mul                  73728
# /onnx::Conv                 23592960
# /onnx::BatchNormalization   40960
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   245760
# /onnx::Conv                 1105920
# /onnx::BatchNormalization   245760
# /onnx::GlobalAveragePool    122880
# /onnx::Conv                 153600
# /onnx::Conv                 153600
# /onnx::Mul                  122880
# /onnx::Conv                 39321600
# /onnx::BatchNormalization   40960
# /onnx::Add                  20480
# /onnx::Conv                 26214400
# /onnx::BatchNormalization   163840
# /onnx::MaxPool              80640
# /onnx::GlobalAveragePool    81920
# /onnx::BatchNormalization   5120
# /onnx::Gemm                 1310720
# /onnx::Relu                 1024
# /onnx::BatchNormalization   1024
# /onnx::Gemm                 1536
# -------------------------   --------
# Input size: (1, 3, 240, 240)
# 718,097,040 FLOPs or approx. 0.72 GFLOPs
# (718097040,
#  [['/onnx::Conv', 12902400],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::Conv', 4147200],
#   ['/onnx::BatchNormalization', 921600],
#   ['/onnx::GlobalAveragePool', 460800],
#   ['/onnx::Conv', 256],
#   ['/onnx::Conv', 256],
#   ['/onnx::Mul', 460800],
#   ['/onnx::Conv', 7372800],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Conv', 2073600],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::GlobalAveragePool', 230400],
#   ['/onnx::Conv', 64],
#   ['/onnx::Conv', 64],
#   ['/onnx::Mul', 230400],
#   ['/onnx::Conv', 3686400],
#   ['/onnx::BatchNormalization', 460800],
#   ['/onnx::Add', 230400],
#   ['/onnx::Conv', 22118400],
#   ['/onnx::BatchNormalization', 2764800],
#   ['/onnx::Conv', 3110400],
#   ['/onnx::BatchNormalization', 691200],
#   ['/onnx::GlobalAveragePool', 345600],
#   ['/onnx::Conv', 384],
#   ['/onnx::Conv', 384],
#   ['/onnx::Mul', 345600],
#   ['/onnx::Conv', 8294400],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 4665600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::GlobalAveragePool', 518400],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 518400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 172800],
#   ['/onnx::Add', 86400],
#   ['/onnx::Conv', 12441600],
#   ['/onnx::BatchNormalization', 1036800],
#   ['/onnx::Conv', 3240000],
#   ['/onnx::BatchNormalization', 259200],
#   ['/onnx::GlobalAveragePool', 129600],
#   ['/onnx::Conv', 864],
#   ['/onnx::Conv', 864],
#   ['/onnx::Mul', 129600],
#   ['/onnx::Conv', 5184000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 5400000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::GlobalAveragePool', 216000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 216000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 72000],
#   ['/onnx::Add', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 432000],
#   ['/onnx::Conv', 486000],
#   ['/onnx::BatchNormalization', 108000],
#   ['/onnx::GlobalAveragePool', 54000],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Conv', 2400],
#   ['/onnx::Mul', 54000],
#   ['/onnx::Conv', 4320000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 972000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 36000],
#   ['/onnx::Add', 18000],
#   ['/onnx::Conv', 8640000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::Conv', 2700000],
#   ['/onnx::BatchNormalization', 216000],
#   ['/onnx::GlobalAveragePool', 108000],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Conv', 9600],
#   ['/onnx::Mul', 108000],
#   ['/onnx::Conv', 12096000],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 3780000],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::GlobalAveragePool', 151200],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 151200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 50400],
#   ['/onnx::Add', 25200],
#   ['/onnx::Conv', 16934400],
#   ['/onnx::BatchNormalization', 302400],
#   ['/onnx::Conv', 1075200],
#   ['/onnx::BatchNormalization', 86016],
#   ['/onnx::GlobalAveragePool', 43008],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Conv', 18816],
#   ['/onnx::Mul', 43008],
#   ['/onnx::Conv', 8257536],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 1843200],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 24576],
#   ['/onnx::Add', 12288],
#   ['/onnx::Conv', 14155776],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::Conv', 663552],
#   ['/onnx::BatchNormalization', 147456],
#   ['/onnx::GlobalAveragePool', 73728],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Conv', 55296],
#   ['/onnx::Mul', 73728],
#   ['/onnx::Conv', 23592960],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::Conv', 1105920],
#   ['/onnx::BatchNormalization', 245760],
#   ['/onnx::GlobalAveragePool', 122880],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Conv', 153600],
#   ['/onnx::Mul', 122880],
#   ['/onnx::Conv', 39321600],
#   ['/onnx::BatchNormalization', 40960],
#   ['/onnx::Add', 20480],
#   ['/onnx::Conv', 26214400],
#   ['/onnx::BatchNormalization', 163840],
#   ['/onnx::MaxPool', 80640],
#   ['/onnx::GlobalAveragePool', 81920],
#   ['/onnx::BatchNormalization', 5120],
#   ['/onnx::Gemm', 1310720],
#   ['/onnx::Relu', 1024],
#   ['/onnx::BatchNormalization', 1024],
#   ['/onnx::Gemm', 1536]])

# %% [markdown]
# ### Save Weights

# %% [markdown]
# ### Analysis
# Using Fast.ai **ClassificationInterpretation** class to aggregate performance metrics and other insights.
#
# Docs for ClassificationInterpretation: https://docs.fast.ai/vision.learner.html#ClassificationInterpretation

# %%
class ImageEmbeddings(): 
  '''
  PyTorch Hook for storing linear features of images.
  Args:
    - m --> type:nn.Module --> Linear Layer of model. 
  '''
  features=None
  def __init__(self, m): 
        self.hook = m.register_forward_hook(self.hook_fn)
        self.features = None

  def hook_fn(self, module, input, output): 
        out = output.detach().cpu().numpy()
        if isinstance(self.features, type(None)):
            self.features = out
        else:
            self.features = np.row_stack((self.features, out))

  def remove(self): 
        self.hook.remove()

# %%
def df_for_projection(dataset, train_set=True):
  """
  Generates a DF from Fastai ImageDataBunch.
  Args:
    - dataset -> type:ImageDataBunch --> Learner data.
    - train_set -> type:bool --> Indicates whether training or test set 
  """
  df=None
  if train_set:
    img_path = [str(x) for x in (list(dataset.train_ds.items) +list(dataset.valid_ds.items))]
    label = [dataset.classes[x] for x in (list(dataset.train_ds.y.items) +list(dataset.valid_ds.y.items))]
    label_id = [x for x in (list(dataset.train_ds.y.items) +list(dataset.valid_ds.y.items))]
    df = pd.DataFrame({'img_path': img_path, 'label': label, 'label_id': label_id})
  else: 
    img_path = [str(x) for x in (list(dataset.test_ds.items))]
    label = [dataset.classes[x] for x in (list(dataset.test_ds.y.items))]
    label_id = [x for x in (list(dataset.test_ds.y.items))]
    df = pd.DataFrame({'img_path': img_path, 'label': label, 'label_id': label_id})
  return df

# %%
def append_features(proj_df, embeddings):
  """
  Appends a new column of ImageEmbeddings to projection DF.
  Args:
  - proj_df -> type:DataFrame --> projection DF.
  - embeddings -> type:list --> List of linear features from a model.
  """
  feature_vector = np.array(embeddings.features)
  x=feature_vector.tolist()
  proj_df['img_repr'] = x
  return proj_df

# %%
def project_data(df, components=3, perplexity=50, iterate=500):
  """
  Automates performing TSNE on a projection DF, and apppending 
  results for each component as a new column on the projection DF.
  Args:
  - df --> type:DataFrame --> projection DF
  - components, perplexity, iterate --> type:int --> TSNE hyperparams. 
  """
  img_repr_matrix = [list(x) for x in df['img_repr'].values]
  tsne = TSNE(n_components=components, 
                    verbose=10, 
                    init='pca', 
                    perplexity=perplexity, 
                    n_iter=iterate, 
                    n_iter_without_progress=100)
  
  tsne_results_3 = tsne.fit_transform(img_repr_matrix)
  df['tsne1'] = tsne_results_3[:,0]
  df['tsne2'] = tsne_results_3[:,1]
  df['tsne3'] = tsne_results_3[:,2]
  return df

# %%
train_projection_df = df_for_projection(learn.data)
train_projection_df.head()
# Out:
#                                             img_path      label  label_id
# 0  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 1  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 2  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 3  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2
# 4  /content/drive/My Drive/fast_covid_net/data/tr...  pneumonia         2

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
#Run through training set one time to hook embeddings
train_features = learn.model[1][4]
train_embeddings = ImageEmbeddings(train_features)
_= learn.get_preds(data.train_ds)
_= learn.get_preds(DatasetType.Valid)

# %%
print(f'Train Embedding Size: {len(train_embeddings.features)}')
# Out:
# Train Embedding Size: 13630

# %%
train_projection_df = append_features(train_projection_df, train_embeddings)
train_projection_df.head()
# Out:
#                                             img_path  ...                                           img_repr
# 0  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [10.839759826660156, -43.84104537963867, -65.2...
# 1  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [49.09904098510742, 17.568862915039062, -108.3...
# 2  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [50.40871810913086, -34.56901931762695, -139.1...
# 3  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [-35.73502731323242, -16.280309677124023, 17.4...
# 4  /content/drive/My Drive/fast_covid_net/data/tr...  ...  [66.1119384765625, -57.34610366821289, -120.56...
#
# [5 rows x 4 columns]

# %%
train_projection_df = project_data(train_projection_df)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 13630 samples in 1.031s...
# [t-SNE] Computed neighbors for 13630 samples in 25.452s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13630
# [t-SNE] Computed conditional probabilities for sample 2000 / 13630
# [t-SNE] Computed conditional probabilities for sample 3000 / 13630
# [t-SNE] Computed conditional probabilities for sample 4000 / 13630
# [t-SNE] Computed conditional probabilities for sample 5000 / 13630
# [t-SNE] Computed conditional probabilities for sample 6000 / 13630
# [t-SNE] Computed conditional probabilities for sample 7000 / 13630
# [t-SNE] Computed conditional probabilities for sample 8000 / 13630
# [t-SNE] Computed conditional probabilities for sample 9000 / 13630
# [t-SNE] Computed conditional probabilities for sample 10000 / 13630
# [t-SNE] Computed conditional probabilities for sample 11000 / 13630
# [t-SNE] Computed conditional probabilities for sample 12000 / 13630
# [t-SNE] Computed conditional probabilities for sample 13000 / 13630
# [t-SNE] Computed conditional probabilities for sample 13630 / 13630
# [t-SNE] Mean sigma: 35.938604
# [t-SNE] Computed conditional probabilities in 1.998s
# [t-SNE] Iteration 50: error = 68.7515030, gradient norm = 0.0499501 (50 iterations in 46.019s)
# [t-SNE] Iteration 100: error = 68.2683487, gradient norm = 0.0344214 (50 iterations in 46.176s)
# [t-SNE] Iteration 150: error = 64.7801437, gradient norm = 0.0056276 (50 iterations in 46.168s)
# [t-SNE] Iteration 200: error = 61.3055878, gradient norm = 0.0004785 (50 iterations in 46.224s)
# [t-SNE] Iteration 250: error = 62.2817764, gradient norm = 0.0179010 (50 iterations in 46.078s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.281776
# [t-SNE] Iteration 300: error = 2.1759272, gradient norm = 0.0002991 (50 iterations in 45.895s)
# [t-SNE] Iteration 350: error = 2.3721809, gradient norm = 0.0001047 (50 iterations in 46.197s)
# [t-SNE] Iteration 400: error = 1.7190130, gradient norm = 0.0000812 (50 iterations in 46.474s)
# [t-SNE] Iteration 450: error = 1.6243417, gradient norm = 0.0000537 (50 iterations in 39.741s)
# [t-SNE] Iteration 500: error = 1.5996292, gradient norm = 0.0000403 (50 iterations in 34.785s)
# [t-SNE] KL divergence after 500 iterations: 1.599629

# %%
#Visualize Img Distribution in 3 Dimensions
train_projection_df.to_parquet('similar_images')
px.scatter_3d(train_projection_df, 
              x='tsne1', 
              y='tsne2', 
              z='tsne3', 
              color='label', 
              title="Train Set Distribution - Scatter Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d19266a8-37ac-4c78-ba18-0f7bed5ab3ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d19266a8-37ac-4c78-ba18-0f7bed5ab3ad")) {
#                     Plotly.newPlot(
#                         'd19266a8-37ac-4c78-ba18-0f7bed5ab3ad',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "label=pneumonia<br>tsne1=%{x}<br>tsne2=%{y}<br>tsne3=%{z}", "legendgroup": "label=pneumonia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "label=pneumonia", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1064.285888671875, 550.4646606445312, -52.38298034667969, 2025.7786865234375, -324.7994689941406, 17.608430862426758, -799.3777465820312, -1636.0704345703125, 1932.1500244140625, 462.76129150390625, 1109.70703125, 1177.1915283203125, -60.8690071105957, 321.3701477050781, -1157.39794921875, 950.6953125, 84.4044418334961, 2779.39892578125, 1375.546630859375, 55.24003219604492, 3008.865234375, 4496.6494140625, 232.70790100097656, -678.9734497070312, 115.56755828857422, 966.5162353515625, -949.0827026367188, 859.4718017578125, 322.05963134765625, 261.44171142578125, 1956.09521484375, -358.2264099121094, -1544.0765380859375, 14.780994415283203, -147.1986846923828, 34.43202590942383, 5023.80859375, -1264.3492431640625, 10558.982421875, -1993.2689208984375, 155.49862670898438, -844.78369140625, -1959.3436279296875, -1546.97314453125, -479.737548828125, 267.8003234863281, -1069.9620361328125, 1306.4736328125, 244.5865020751953, 227.65985107421875, -1685.6826171875, 121.3079833984375, -4098.58837890625, -1903.837890625, 196.0252227783203, 1112.5596923828125, -202.99208068847656, -154.36610412597656, 1524.09375, 219.61447143554688, -1395.860107421875, 623.037109375, -45.327022552490234, 2893.50244140625, 1651.3431396484375, 217.29649353027344, -142.0927734375, 1885.6243896484375, 849.95849609375, 58.291839599609375, 1044.847900390625, -1470.3193359375, -1327.23779296875, 154.28277587890625, 4691.138671875, -1311.0765380859375, 6878.005859375, 179.98785400390625, 496.4795837402344, -2316.833984375, 1143.4425048828125, -390.8555603027344, 2666.698486328125, 711.8029174804688, 724.5797729492188, -2623.717529296875, 3094.81201171875, 972.510498046875, -771.34033203125, -1322.273681640625, 5594.14794921875, 1224.8565673828125, -857.2631225585938, 368.0444641113281, -1176.51904296875, 784.496826171875, 2397.125732421875, 1205.5614013671875, -1604.0313720703125, 1234.89404296875, -82.47280883789062, -101.46510314941406, 1498.7200927734375, -1688.380126953125, 1487.570556640625, -2000.8026123046875, -2312.001220703125, -2812.887939453125, -99.17131805419922, -182.55227661132812, 878.9647827148438, 1229.0009765625, 1444.761474609375, 340.4896545410156, -750.6476440429688, -2451.268798828125, -1222.15625, -919.0405883789062, -466.91961669921875, 80.94955444335938, -479.7755126953125, 7708.9931640625, -1209.6640625, 329.0953369140625, -195.3641357421875, 1102.0018310546875, 1016.628662109375, 1699.1168212890625, 208.76023864746094, -3412.369384765625, -2899.991943359375, 443.78558349609375, 282.4604187011719, 412.2309875488281, -119.25528717041016, -1712.1038818359375, 331.2312316894531, 275.90557861328125, 1395.6002197265625, 531.0933837890625, -2624.13330078125, 170.53363037109375, -202.3446044921875, 356.8348693847656, -2089.51806640625, -2549.358642578125, -121.67511749267578, -530.365478515625, -1512.9151611328125, -1264.9739990234375, -144.32704162597656, -3353.635009765625, 1133.0054931640625, -1046.65087890625, -975.2667846679688, 49.67329025268555, 298.4461975097656, -597.1357421875, 601.0396118164062, -1347.602294921875, 907.2083740234375, -1001.3067626953125, 682.9309692382812, 941.0473022460938, 92.11803436279297, 1190.4649658203125, 332.78009033203125, -322.6991271972656, -1732.49560546875, -1715.918701171875, -108.77191925048828, 903.1151123046875, 2338.28955078125, -1597.145751953125, -520.4765625, -877.66064453125, 1977.15576171875, 204.0789337158203, 1048.13916015625, 849.7485961914062, -1654.1220703125, -1673.9783935546875, -1160.02783203125, -861.9431762695312, -1346.6002197265625, -1083.5943603515625, -645.9635620117188, 817.8071899414062, -1225.7322998046875, -1128.7005615234375, -666.7677612304688, ...

# %%
train_projection_df.describe()
# Out:
#            label_id         tsne1         tsne2         tsne3
# count  13630.000000  13630.000000  13630.000000  13630.000000
# mean       1.384299      0.357754     -0.043984     -0.207545
# std        0.517579   2116.098145   1552.961914    729.939453
# min        0.000000  -6073.887207  -7868.723145  -6897.241211
# 25%        1.000000  -1265.336639  -1290.698853   -428.622223
# 50%        1.000000    -83.919712   -272.616241      3.502648
# 75%        2.000000    612.051956    897.781372    507.909157
# max        2.000000  21697.929688  10891.002930   5805.587891

# %%
'''
plot_top_losses() --> https://docs.fast.ai/vision.learner.html#_cl_int_plot_top_losses
Show images in top_losses along with their prediction, actual, loss, 
and probability of actual class.
'''
interp.plot_top_losses(9, figsize=(13,13))

# %%
'''
plot_confusion_matrix() --> 
https://docs.fast.ai/train.html#ClassificationInterpretation.plot_confusion_matrix
Plot the confusion matrix, with title and using cmap.
'''
interp.plot_confusion_matrix(figsize=(8,8), dpi=60)

# %%
'''
most_confused() --> 
https://docs.fast.ai/train.html#ClassificationInterpretation.most_confused
Sorted descending list of largest non-diagonal entries of confusion matrix, 
presented as actual, predicted, number of occurrences.
'''
print("Most Confused Classes")
interp.most_confused(min_val=2)
# Out:
# Most Confused Classes
# [('normal', 'pneumonia', 60),
#  ('pneumonia', 'normal', 52),
#  ('pneumonia', 'COVID-19', 2)]

# %%
print(interp.confusion_matrix())
# Out:
# [[  46    1    1]
#  [   1 1549   60]
#  [   2   52 1014]]

# %%
def get_metrics(cm):
  """
  Tabulates relevant metrics for medical diagnosis from stored rows/diagonal 
  entries of confusion matrics; Returns an array of metrics:true positives (tp), 
  false positives (fp), true negatives (tn), and false negatives (fn) for each
  class in a 3x3 confusion matrix (12 int64 values).
  Args:
    cm --> type:np.darray --> a confusion matrix.
  """
  tp_c1 = cm[0][0]
  fp_c1 = cm[1][0] + cm[2][0]
  tn_c1 = np.sum(cm) - tp_c1
  fn_c1 = cm[0][1] + cm[0][2]

  tp_c2 = cm[1][1]
  fp_c2 = cm[0][1] + cm[2][1]
  tn_c2 = np.sum(cm) - tp_c2
  fn_c2 = cm[1][0] + cm[1][2]

  tp_c3 = cm[2][2]
  fp_c3 = cm[0][2] + cm[1][2]
  tn_c3 = np.sum(cm) - tp_c3
  fn_c3 = cm[2][0] + cm[2][1]

  return [tp_c1,fp_c1,tn_c1,fn_c1,tp_c2,fp_c2,tn_c2,fn_c2, tp_c3,fp_c3,tn_c3,fn_c3]

# %%
train_conf_matrix = interp.confusion_matrix()
training_metrics = get_metrics(train_conf_matrix)
print(training_metrics)
# Out:
# [46, 3, 2680, 2, 1549, 53, 1177, 61, 1014, 61, 1712, 54]

# %%
#Precision for each class 
covid_precision = training_metrics[0]/(training_metrics[0]+training_metrics[1])
norm_precision = training_metrics[4]/(training_metrics[4]+training_metrics[5])
pneum_precision = training_metrics[8]/(training_metrics[8]+training_metrics[9])

train_precision_scores = {
    "COVID-19": covid_precision,
    "NORMAL": norm_precision,
    "PNEUMONIA": pneum_precision
}

train_precision_scores = pd.DataFrame(train_precision_scores, 
                                      columns=train_precision_scores.keys(), 
                                      index=[0])
print("Precision Scores:")
train_precision_scores
# Out:
# Precision Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.938776  0.966916   0.943256

# %%
#Recall for each class 
covid_recall = training_metrics[0]/(training_metrics[0]+training_metrics[3])
norm_recall = training_metrics[4]/(training_metrics[4]+training_metrics[7])
pneum_recall = training_metrics[8]/(training_metrics[8]+training_metrics[11])

train_sensitivity_scores = {
    "COVID-19": covid_recall, 
    "NORMAL": norm_recall,
    "PNEUMONIA": pneum_recall
}

train_sensitivity_scores = pd.DataFrame(train_sensitivity_scores, 
                         columns=train_sensitivity_scores.keys(), 
                         index=[0])
print("Sensitivity Scores:")
train_sensitivity_scores
# Out:
# Sensitivity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.958333  0.962112   0.949438

# %%
#F1 Score for each class 
covid_f1 = 2*(covid_precision*covid_recall)/(covid_precision+covid_recall)
norm_f1 = 2 * (norm_precision*norm_recall)/(norm_precision + norm_recall)
pneum_f1 = 2 * (pneum_precision*pneum_recall)/(pneum_precision+pneum_recall)

train_f1_scores = {
    "COVID-19": covid_f1,
    "NORMAL": norm_f1,
    "PNEUMONIA": pneum_f1
}

train_f1_scores = pd.DataFrame(train_f1_scores, 
                         columns=train_f1_scores.keys(), 
                         index=[0])
print("F1 Scores:")
train_f1_scores
# Out:
# F1 Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.948454  0.964508   0.946337

# %%
#Specificity for each class 
covid_specificity = training_metrics[2]/(training_metrics[2]+training_metrics[1])
norm_specificity = training_metrics[6]/(training_metrics[6]+training_metrics[5])
pneum_specificity = training_metrics[10]/(training_metrics[10]+training_metrics[9])

specificity_scores = {"COVID-19": covid_specificity, 
                      "NORMAL": norm_specificity, 
                      "PNEUMONIA": pneum_specificity}
                      
specificity_df = pd.DataFrame(specificity_scores, 
                              columns=specificity_scores.keys(), 
                              index=[0])
print("Specificity Scores:")
specificity_df
# Out:
# Specificity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.998882  0.956911   0.965595

# %% [markdown]
# ### Inference Test & Results:

# %%
test_labels = pd.read_csv(path/'test_split_v3.csv', header='infer')
test_data_df = test_labels[["fname", "label"]]
print("Test Set Labels:")
test_data_df.head()
# Out:
# Test Set Labels:
#                                                fname      label
# 0  SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9...  pneumonia
# 1  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 2  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 3  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia
# 4  streptococcus-pneumoniae-pneumonia-temporal-ev...  pneumonia

# %%
#Create a Fast.ai ImageList for creating inference data loaders
il = ImageList.from_df(test_data_df, path/'data/test')
ils = il.split_none()
ll = ils.label_from_df()
ll.valid = ll.train
ll.test = ll.train

# %%
#Apply test time transforms (None) 
test_size = 300
ll.transform(tfms=tfms,size=test_size)
#Create DataLoaders 
test_data = ll.databunch(bs=bs)
#Normalize --> Imagenet Stats 
test_data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (1510 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test;
#
# Valid: LabelList (1510 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test;
#
# Test: LabelList (1510 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: CategoryList
# pneumonia,pneumonia,pneumonia,pneumonia,pneumonia
# Path: /content/drive/My Drive/fast_covid_net/data/test

# %%
#Load serialized learner and weights
learn.export(file=path/'e-covidnet.pkl')
test_learn = load_learner(path, file='e-covidnet.pkl')
#Attach test data to Learner 
test_learn.data = test_data

# %%
test_features = test_learn.model[1][4]
test_embeddings = ImageEmbeddings(test_features)

# %%
#Run inference
# %time results = test_learn.get_preds(ds_type=DatasetType.Test)
# Out:
# CPU times: user 5.25 s, sys: 1.23 s, total: 6.48 s
# Wall time: 3min 18s

# %%
print(f'Test Embedding Size: {len(test_embeddings.features)}')
# Out:
# Test Embedding Size: 1510

# %%
testing_projection_df = df_for_projection(test_learn.data, train_set=False)
testing_projection_df.head()
# Out:
#                                             img_path      label  label_id
# 0  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 1  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 2  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 3  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2
# 4  /content/drive/My Drive/fast_covid_net/data/te...  pneumonia         2

# %%
testing_projection_df = append_features(testing_projection_df, test_embeddings)
testing_projection_df.head()
# Out:
#                                             img_path  ...                                           img_repr
# 0  /content/drive/My Drive/fast_covid_net/data/te...  ...  [47.201438903808594, -77.5743408203125, -58.81...
# 1  /content/drive/My Drive/fast_covid_net/data/te...  ...  [45.58774948120117, 12.62635612487793, -82.683...
# 2  /content/drive/My Drive/fast_covid_net/data/te...  ...  [44.3748664855957, 9.219533920288086, -104.567...
# 3  /content/drive/My Drive/fast_covid_net/data/te...  ...  [58.64944839477539, -3.5249671936035156, -106....
# 4  /content/drive/My Drive/fast_covid_net/data/te...  ...  [32.29679870605469, -14.111461639404297, -100....
#
# [5 rows x 4 columns]

# %%
testing_projection_df = project_data(testing_projection_df)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 1510 samples in 0.065s...
# [t-SNE] Computed neighbors for 1510 samples in 0.869s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1510
# [t-SNE] Computed conditional probabilities for sample 1510 / 1510
# [t-SNE] Mean sigma: 94.536456
# [t-SNE] Computed conditional probabilities in 0.217s
# [t-SNE] Iteration 50: error = 44.3487282, gradient norm = 0.0002200 (50 iterations in 1.875s)
# [t-SNE] Iteration 100: error = 44.0653534, gradient norm = 0.0000685 (50 iterations in 1.908s)
# [t-SNE] Iteration 150: error = 43.7615051, gradient norm = 0.0000550 (50 iterations in 1.861s)
# [t-SNE] Iteration 200: error = 43.6724777, gradient norm = 0.0000673 (50 iterations in 1.847s)
# [t-SNE] Iteration 250: error = 43.8094635, gradient norm = 0.0000504 (50 iterations in 1.830s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 43.809464
# [t-SNE] Iteration 300: error = 1.0817904, gradient norm = 0.0000599 (50 iterations in 1.853s)
# [t-SNE] Iteration 350: error = 1.0314429, gradient norm = 0.0000395 (50 iterations in 1.819s)
# [t-SNE] Iteration 400: error = 0.9861737, gradient norm = 0.0000281 (50 iterations in 1.800s)
# [t-SNE] Iteration 450: error = 0.9492343, gradient norm = 0.0000211 (50 iterations in 1.847s)
# [t-SNE] Iteration 500: error = 0.9194469, gradient norm = 0.0000165 (50 iterations in 1.901s)
# [t-SNE] KL divergence after 500 iterations: 0.919447

# %%
#Visualize Img Distribution in 3 Dimensions
testing_projection_df.to_parquet('similar_images')
px.scatter_3d(testing_projection_df, 
              x='tsne1', 
              y='tsne2', 
              z='tsne3', 
              color='label', 
              title="Test Set Distribution - Scatter Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1e797ba-7082-4b7a-bb44-0b0bef6f3a46" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1e797ba-7082-4b7a-bb44-0b0bef6f3a46")) {
#                     Plotly.newPlot(
#                         'c1e797ba-7082-4b7a-bb44-0b0bef6f3a46',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "label=pneumonia<br>tsne1=%{x}<br>tsne2=%{y}<br>tsne3=%{z}", "legendgroup": "label=pneumonia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "label=pneumonia", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1177.936279296875, -2046.353271484375, -2197.39306640625, -1871.0238037109375, -2009.62451171875, -2272.205810546875, -2743.843505859375, -2359.473876953125, -1571.7593994140625, -2077.637939453125, -1452.08544921875, 641.35498046875, -2212.797119140625, -2229.62890625, -2204.93115234375, -2258.370849609375, -833.42626953125, -1707.4759521484375, -1801.483642578125, -2066.858642578125, -2281.792724609375, -1839.9034423828125, -2119.26904296875, -2126.5927734375, -2303.632568359375, -2102.375244140625, -2182.53466796875, -1967.1920166015625, -1711.1383056640625, -797.7991333007812, -2205.05078125, -1977.66845703125, -2078.76806640625, -2612.1923828125, -1687.6365966796875, -1167.19580078125, -2375.89501953125, -2276.146728515625, -831.18896484375, -460.4450988769531, -591.4600219726562, -499.5052185058594, -1762.325439453125, -2521.49267578125, -2318.998291015625, -2058.14599609375, -2161.940673828125, -1512.2371826171875, -2539.428955078125, -2331.74169921875, -2431.203369140625, -1686.624267578125, -2066.991455078125, -2588.217041015625, -2231.488037109375, -1945.53759765625, -1306.822998046875, -1539.502685546875, -1822.77783203125, -2193.187744140625, -2117.493896484375, -1510.9617919921875, -2206.946044921875, -2139.312255859375, -2101.499755859375, -2001.2025146484375, -1904.5941162109375, -2359.807861328125, -2181.732421875, -1261.3909912109375, -1640.6785888671875, -1691.1436767578125, -1621.309326171875, -2356.791015625, -2047.712158203125, -2033.3436279296875, -2370.5185546875, -1708.452880859375, -2638.569091796875, -2339.343994140625, -1970.5093994140625, -1991.0853271484375, -1997.7174072265625, -2060.17822265625, -1989.8612060546875, -712.22509765625, -2366.891357421875, -2050.173095703125, -1935.07666015625, 1085.074951171875, -2039.645263671875, -2378.225341796875, -1745.73291015625, -1810.2706298828125, -2118.095947265625, -1974.7333984375, -1845.9022216796875, -1480.7723388671875, -240.31886291503906, -627.1551513671875, -1452.085205078125, -2487.68994140625, -2354.666748046875, -2040.816650390625, -2180.188720703125, -2170.7822265625, -389.569580078125, -2464.35986328125, -1204.1904296875, -2329.44091796875, -2357.50439453125, -2314.85107421875, -2213.930908203125, -106.49166870117188, -2539.97314453125, -1813.667236328125, -2021.9141845703125, -2195.49169921875, -2398.325927734375, -2281.754150390625, -2598.493408203125, -1870.4349365234375, -1694.61376953125, -1096.035888671875, -1538.8922119140625, -1952.8287353515625, -2187.527587890625, -2156.303955078125, -2474.738525390625, -2005.3287353515625, -2607.990478515625, -2049.278076171875, -2323.921142578125, -1609.8916015625, -1997.25146484375, -2004.5946044921875, -2383.876953125, -1312.826904296875, -1941.2301025390625, -363.8271789550781, -1922.3026123046875, -1963.1678466796875, -274.7315368652344, -1505.0091552734375, -1509.8824462890625, -1423.3865966796875, -2430.20361328125, -2163.690185546875, -2130.19677734375, -1805.5054931640625, -2407.26025390625, -2142.462890625, -2302.566650390625, -1965.983642578125, -1983.199951171875, -2067.581298828125, -2460.92578125, -1841.885498046875, -2281.063720703125, -1868.65380859375, -2173.048828125, -1651.8477783203125, -1963.8775634765625, -1919.760986328125, -2155.94921875, -1789.25830078125, -2095.569580078125, -1838.7486572265625, -1924.252685546875, -2261.385986328125, -2326.0498046875, -2439.151611328125, -1848.608642578125, -2200.57373046875, -2091.916259765625, -2516.143310546875, -1939.9111328125, -2006.244140625, -1428.694580078125, -2692.316650390625, -2240.70703125, -2422.090576171875, -2237.72412109375, -2283.187744140625, -1805.088134765625, -2051.55224609375, -1786.68 ...

# %%
testing_projection_df.describe()
# Out:
#           label_id        tsne1        tsne2        tsne3
# count  1510.000000  1510.000000  1510.000000  1510.000000
# mean      1.372848     0.001760     0.000583    -0.001450
# std       0.524475  1974.391602   509.667542   241.281967
# min       0.000000 -2763.546143 -1975.002808  -435.973206
# 25%       1.000000 -1948.774689  -330.098434  -162.464455
# 50%       1.000000   131.579506    17.142082   -34.410297
# 75%       2.000000  1266.334503   324.780128   109.589823
# max       2.000000  7182.369629  3407.587158  3628.969971

# %% [markdown]
# ### Inference Test Results

# %%
#store rows/diagonal entries of confusion matrics to tabulate metrics
test_interp = ClassificationInterpretation.from_learner(test_learn)
losses,idxs = test_interp.top_losses()
len(test_data.test_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
test_interp.plot_confusion_matrix(figsize=(8,8), dpi=60)

# %%
test_interp.most_confused(min_val=2)
# Out:
# [('normal', 'pneumonia', 41),
#  ('pneumonia', 'normal', 33),
#  ('COVID-19', 'normal', 3)]

# %%
test_conf_matrix = test_interp.confusion_matrix()
inference_metrics = get_metrics(test_conf_matrix)
print(inference_metrics)
# Out:
# [28, 1, 1482, 3, 844, 36, 666, 41, 560, 41, 950, 34]

# %%
#Precision for each class 
test_covid_precision = inference_metrics[0]/(inference_metrics[0]+inference_metrics[1])
test_norm_precision = inference_metrics[4]/(inference_metrics[4]+inference_metrics[5])
test_pneum_precision = inference_metrics[8]/(inference_metrics[8]+inference_metrics[9])

test_precision_scores = {
    "COVID-19": test_covid_precision,
    "NORMAL": test_norm_precision,
    "PNEUMONIA": test_pneum_precision
}

test_precision_scores = pd.DataFrame(test_precision_scores, 
                                      columns=train_precision_scores.keys(), 
                                      index=[0])
print("Precision Scores:")
test_precision_scores
# Out:
# Precision Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.965517  0.959091    0.93178

# %%
#Recall for each class 
test_covid_recall = inference_metrics[0]/(inference_metrics[0]+inference_metrics[3])
test_norm_recall = inference_metrics[4]/(inference_metrics[4]+inference_metrics[7])
test_pneum_recall = inference_metrics[8]/(inference_metrics[8]+inference_metrics[11])

test_sensitivity_scores = {
    "COVID-19": test_covid_recall, 
    "NORMAL": test_norm_recall,
    "PNEUMONIA": test_pneum_recall
}

test_sensitivity_scores = pd.DataFrame(test_sensitivity_scores, 
                         columns=test_sensitivity_scores.keys(), 
                         index=[0])
print("Sensitivity Scores:")
test_sensitivity_scores
# Out:
# Sensitivity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.903226  0.953672   0.942761

# %%
#F1 Score for each class 
test_covid_f1 = 2*(test_covid_precision*test_covid_recall)/(test_covid_precision+test_covid_recall)
test_norm_f1 = 2 * (test_norm_precision*test_norm_recall)/(test_norm_precision + test_norm_recall)
test_pneum_f1 = 2 * (test_pneum_precision*test_pneum_recall)/(test_pneum_precision+test_pneum_recall)

test_f1_scores = {
    "COVID-19": test_covid_f1,
    "NORMAL": test_norm_f1,
    "PNEUMONIA": test_pneum_f1
}

test_f1_scores = pd.DataFrame(test_f1_scores, 
                         columns=test_f1_scores.keys(), 
                         index=[0])
print("F1 Scores:")
test_f1_scores
# Out:
# F1 Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.933333  0.956374   0.937238

# %%
#Specificity for each class 
test_covid_specificity = inference_metrics[2]/(inference_metrics[2]+inference_metrics[1])
test_norm_specificity = inference_metrics[6]/(inference_metrics[6]+inference_metrics[5])
test_pneum_specificity = inference_metrics[10]/(inference_metrics[10]+inference_metrics[9])

test_specificity_scores = {"COVID-19": test_covid_specificity, 
                      "NORMAL": test_norm_specificity, 
                      "PNEUMONIA": test_pneum_specificity}
                      
test_specificity_df = pd.DataFrame(test_specificity_scores, 
                              columns=test_specificity_scores.keys(), 
                              index=[0])
print("Specificity Scores:")
test_specificity_df
# Out:
# Specificity Scores:
#    COVID-19    NORMAL  PNEUMONIA
# 0  0.999326  0.948718   0.958628

# %%
accuracy(*test_learn.TTA())
# Out:
# tensor(0.9464)

# %%
#save serialized fastai learner and recorder info
#import torch
defaults.device = torch.device('cpu')
#learn = get_learner(data2).load('eff_covid_2')
learn.export(file=path/'e-covidnet.pkl')
#save model state/weights (.pth file) for cpu inference
torch.save(learn.model.state_dict(), path/"e-covidnet.pth")

# %%
#Compress model files for use in FastAPI
import shutil
shutil.make_archive('models', 'zip', 'models')
# Out:
# '/content/models.zip'
